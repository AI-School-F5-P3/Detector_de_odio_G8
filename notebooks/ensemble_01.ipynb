# %% [markdown]
# # Ensemble

# %%
import pandas as pd 

# Cargar el nuevo archivo CSV limpio proporcionado por el usuario
data = pd.read_csv('../data/cleaned_data.csv')

# Verificar la estructura del archivo para asegurar que las columnas necesarias estén presentes
data.head()
# Out:
#                                         Cleaned_Text  Any_Hate  IsToxic  \
# 0  people would take step back make case anyone e...     False    False
# 1  law enforcement trained shoot apprehend traine...      True     True
# 2  dont reckon life matter banner held white cunt...      True     True
# 3  large number people like police officer called...     False    False
# 4  arab dude absolutely right shot 6 extra time s...     False    False
#
#    IsAbusive  IsThreat  IsProvocative  IsObscene  IsHatespeech  IsRacist  \
# 0      False     False          False      False         False     False
# 1       True     False          False      False         False     False
# 2       True     False          False       True         False     False
# 3      False     False          False      False         False     False
# 4      False     False          False      False         False     False
#
#    IsNationalist  IsSexist  IsHomophobic  IsReligiousHate  IsRadicalism
# 0          False     False         False            False         False
# 1          False     False         False            False         False
# 2          False     False         False            False         False
# 3          False     False         False            False         False
# 4          False     False         False            False         False

# %% [markdown]
# ## Voting Classifier (Ensemble de Votación)

# %%
import optuna
from sklearn.ensemble import VotingClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# Vectorización con TF-IDF
tfidf = TfidfVectorizer(max_features=1500, ngram_range=(1, 3))
x_tfidf = tfidf.fit_transform(data['Cleaned_Text'])
y = data['Any_Hate']

# Dividir en conjunto de entrenamiento y prueba
x_train, x_test, y_train, y_test = train_test_split(x_tfidf, y, test_size=0.2, random_state=42)

# Función de objetivo para Optuna
def objective(trial):
    # Optimización de hiperparámetros del modelo SVM
    c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
    kernel_svm = trial.suggest_categorical('kernel_svm', ['linear', 'rbf'])
    if kernel_svm == 'rbf':
        gamma_svm = trial.suggest_categorical('gamma_svm', ['scale', 'auto'])
    else:
        gamma_svm = 'scale'  # predeterminado cuando no se usa 'rbf'

    # Optimización de hiperparámetros para Random Forest
    n_estimators_rf = trial.suggest_int('n_estimators_rf', 10, 50, step=5)
    max_features_rf = trial.suggest_categorical('max_features_rf', ['sqrt', 'log2'])

    # Optimización de hiperparámetros para Regresión Logística
    c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)

    # Configuración de modelos base con los hiperparámetros ajustados
    svm = SVC(C=c_svm, kernel=kernel_svm, gamma=gamma_svm, probability=True, random_state=42)
    rf = RandomForestClassifier(n_estimators=n_estimators_rf, max_depth=50, min_samples_leaf=3, 
                                max_features=max_features_rf, random_state=42)
    logreg = LogisticRegression(C=c_logreg, max_iter=1000, random_state=42)
    
    # Ajuste de pesos para el Voting Classifier
    weight_svm = trial.suggest_float('weight_svm', 0.1, 1.0)
    weight_rf = trial.suggest_float('weight_rf', 0.1, 1.0)
    weight_logreg = trial.suggest_float('weight_logreg', 0.1, 1.0)
    
    # Crear el ensemble con VotingClassifier
    voting_clf = VotingClassifier(estimators=[
        ('svm', svm),
        ('rf', rf),
        ('logreg', logreg)
    ], voting='soft', weights=[weight_svm, weight_rf, weight_logreg])
    
    # Entrenar y evaluar el ensemble
    voting_clf.fit(x_train, y_train)
    y_pred = voting_clf.predict(x_test)
    score = f1_score(y_test, y_pred, average='weighted')
    return score

# Crear el estudio de Optuna y optimizar
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Resultados de Optuna
print("Mejores parámetros:", study.best_params)
print("Mejor F1 ponderado:", study.best_value)

# Entrenamiento final con los mejores parámetros encontrados
best_params = study.best_params
svm = SVC(C=best_params['c_svm'], kernel=best_params['kernel_svm'], gamma=best_params.get('gamma_svm', 'scale'), probability=True, random_state=42)
rf = RandomForestClassifier(n_estimators=best_params['n_estimators_rf'], max_depth=50, min_samples_leaf=3, 
                            max_features=best_params['max_features_rf'], random_state=42)
logreg = LogisticRegression(C=best_params['c_logreg'], max_iter=1000, random_state=42)

# Crear el Voting Classifier final
voting_clf = VotingClassifier(estimators=[
    ('svm', svm),
    ('rf', rf),
    ('logreg', logreg)
], voting='soft', weights=[best_params['weight_svm'], best_params['weight_rf'], best_params['weight_logreg']])

voting_clf.fit(x_train, y_train)
y_pred = voting_clf.predict(x_test)

# Informe de clasificación final
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=['No Hate', 'Hate']))
# Out:
# [I 2024-11-11 17:30:24,915] A new study created in memory with name: no-name-116ea02d-0235-44f2-9437-6c8ff4cc4a9a
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:25,176] Trial 0 finished with value: 0.7017737272155878 and parameters: {'c_svm': 0.49651769730805356, 'kernel_svm': 'linear', 'n_estimators_rf': 50, 'max_features_rf': 'log2', 'c_logreg': 0.5777810769335261, 'weight_svm': 0.5759355475044479, 'weight_rf': 0.2355441543497304, 'weight_logreg': 0.7981429319088901}. Best is trial 0 with value: 0.7017737272155878.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:25,423] Trial 1 finished with value: 0.6901755846514795 and parameters: {'c_svm': 4.1392133440208925, 'kernel_svm': 'linear', 'n_estimators_rf': 20, 'max_features_rf': 'log2', 'c_logreg': 0.21256612174021006, 'weight_svm': 0.6623211848741493, 'weight_rf': 0.3585093647355646, 'weight_logreg': 0.8323952607136501}. Best is trial 0 with value: 0.7017737272155878.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:25,667] Trial 2 finished with value: 0.6976515455640304 and parameters: {'c_svm': 0.20989682340172386, 'kernel_svm': 'linear', 'n_estimators_rf': 40, 'max_features_rf': 'log2', 'c_logreg': 0.5827367146198148, 'weight_svm': 0.4336453572542597, 'weight_rf': 0.44437792276604315, 'weight_logreg': 0.647198341897256}. Best is trial 0 with value: 0.7017737272155878.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:25,887] Trial 3 finished with value: 0.7243464665415885 and parameters: {'c_svm': 1.0277693718104475, 'kernel_svm': 'linear', 'n_estimators_rf': 25, 'max_features_rf': 'log2', 'c_logreg': 0.22857735193722165, 'weight_svm': 0.9346693109726917, 'weight_rf': 0.2483310791944984, 'weight_logreg': 0.23206023477850599}. Best is trial 3 with value: 0.7243464665415885.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:26,135] Trial 4 finished with value: 0.720280112044818 and parameters: {'c_svm': 0.18550902294974178, 'kernel_svm': 'linear', 'n_estimators_rf': 40, 'max_features_rf': 'log2', 'c_logreg': 3.199840309706024, 'weight_svm': 0.7771975086903945, 'weight_rf': 0.23381556515617202, 'weight_logreg': 0.31865514628972047}. Best is trial 3 with value: 0.7243464665415885.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:26,393] Trial 5 finished with value: 0.686256038647343 and parameters: {'c_svm': 1.2754593137232906, 'kernel_svm': 'linear', 'n_estimators_rf': 40, 'max_features_rf': 'sqrt', 'c_logreg': 1.0005687449670702, 'weight_svm': 0.2092007150260843, 'weight_rf': 0.10295707116512459, 'weight_logreg': 0.9016854460762501}. Best is trial 3 with value: 0.7243464665415885.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:26,623] Trial 6 finished with value: 0.6995189463838822 and parameters: {'c_svm': 0.8142897775239305, 'kernel_svm': 'linear', 'n_estimators_rf': 20, 'max_features_rf': 'sqrt', 'c_logreg': 0.28539872171726155, 'weight_svm': 0.26183652447532374, 'weight_rf': 0.3324916878016974, 'weight_logreg': 0.9898762083134774}. Best is trial 3 with value: 0.7243464665415885.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:26,840] Trial 7 finished with value: 0.6761352657004831 and parameters: {'c_svm': 0.34615513158386235, 'kernel_svm': 'linear', 'n_estimators_rf': 10, 'max_features_rf': 'sqrt', 'c_logreg': 0.3172419081639014, 'weight_svm': 0.16243397066431248, 'weight_rf': 0.6674106929278824, 'weight_logreg': 0.5566744202230752}. Best is trial 3 with value: 0.7243464665415885.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30
 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 25, 'max_features_rf': 'sqrt', 'c_logreg': 0.6295534728049665, 'weight_svm': 0.37728968652159295, 'weight_rf': 0.15047469713021014, 'weight_logreg': 0.6012394146323513}. Best is trial 41 with value: 0.7403122810529476.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:37,323] Trial 45 finished with value: 0.6986778846153845 and parameters: {'c_svm': 0.2845419030049881, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 30, 'max_features_rf': 'sqrt', 'c_logreg': 0.2848210213421236, 'weight_svm': 0.2868622059787776, 'weight_rf': 0.19959548438615018, 'weight_logreg': 0.7872301863361941}. Best is trial 41 with value: 0.7403122810529476.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:37,616] Trial 46 finished with value: 0.7252269260583631 and parameters: {'c_svm': 0.69700921197665, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 'sqrt', 'c_logreg': 1.1925260424442354, 'weight_svm': 0.7127162584520714, 'weight_rf': 0.3114800713571181, 'weight_logreg': 0.6384427243631682}. Best is trial 41 with value: 0.7403122810529476.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:37,866] Trial 47 finished with value: 0.6990991892703434 and parameters: {'c_svm': 0.19718682687198005, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 20, 'max_features_rf': 'sqrt', 'c_logreg': 1.7094358197135482, 'weight_svm': 0.4902146207400821, 'weight_rf': 0.25265634359522526, 'weight_logreg': 0.8805865626941609}. Best is trial 41 with value: 0.7403122810529476.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:38,161] Trial 48 finished with value: 0.7143227016885554 and parameters: {'c_svm': 0.532461641562909, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 30, 'max_features_rf': 'sqrt', 'c_logreg': 4.3002666942623495, 'weight_svm': 0.5408795124952992, 'weight_rf': 0.4049319178854659, 'weight_logreg': 0.5425544787279333}. Best is trial 41 with value: 0.7403122810529476.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\4100600423.py:32: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:38,458] Trial 49 finished with value: 0.6981954887218046 and parameters: {'c_svm': 1.1203408424778427, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 'sqrt', 'c_logreg': 0.3813933747620578, 'weight_svm': 0.4125625831229983, 'weight_rf': 0.33730875765396384, 'weight_logreg': 0.979578819314044}. Best is trial 41 with value: 0.7403122810529476.
# Mejores parámetros: {'c_svm': 0.542490915984282, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 30, 'max_features_rf': 'sqrt', 'c_logreg': 2.4277841263066318, 'weight_svm': 0.48756306679019423, 'weight_rf': 0.29285584915374074, 'weight_logreg': 0.6929499161084561}
# Mejor F1 ponderado: 0.7403122810529476
#               precision    recall  f1-score   support
#
#      No Hate       0.70      0.76      0.73        93
#         Hate       0.78      0.72      0.75       107
#
#     accuracy                           0.74       200
#    macro avg       0.74      0.74      0.74       200
# weighted avg       0.74      0.74      0.74       200

# %% [markdown]
# ## Stacking Ensemble (Ensemble de Stacking)

# %%
import optuna
from sklearn.ensemble import StackingClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# Vectorización con TF-IDF
tfidf = TfidfVectorizer(max_features=1500, ngram_range=(1, 3))
x_tfidf = tfidf.fit_transform(data['Cleaned_Text'])
y = data['Any_Hate']

# Dividir en conjunto de entrenamiento y prueba
x_train, x_test, y_train, y_test = train_test_split(x_tfidf, y, test_size=0.2, random_state=42)

# Función de objetivo para Optuna
def objective(trial):
    # Optimización de hiperparámetros de los modelos base
    c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
    kernel_svm = trial.suggest_categorical('kernel_svm', ['linear', 'rbf'])
    if kernel_svm == 'rbf':
        gamma_svm = trial.suggest_categorical('gamma_svm', ['scale', 'auto'])
    else:
        gamma_svm = 'scale'  # predeterminado para 'linear'

    n_estimators_rf = trial.suggest_int('n_estimators_rf', 10, 50, step=5)
    max_features_rf = trial.suggest_categorical('max_features_rf', ['sqrt', 'log2', 0.1, 0.2, 0.5])

    c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)

    # Configuración de los modelos base con los hiperparámetros ajustados
    svm = SVC(C=c_svm, kernel=kernel_svm, gamma=gamma_svm, probability=True, random_state=42)
    rf = RandomForestClassifier(n_estimators=n_estimators_rf, max_depth=50, min_samples_leaf=3, 
                                max_features=max_features_rf, random_state=42)
    logreg = LogisticRegression(C=c_logreg, max_iter=1000, random_state=42)
    
    # Selección del meta-modelo de nivel superior
    meta_model_choice = trial.suggest_categorical('meta_model', ['LogisticRegression', 'MultinomialNB'])
    if meta_model_choice == 'LogisticRegression':
        c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
        meta_model = LogisticRegression(C=c_meta, max_iter=1000, random_state=42)
    else:
        alpha_meta = trial.suggest_float('alpha_meta', 0.1, 1.0)
        meta_model = MultinomialNB(alpha=alpha_meta)

    # Configuración del Stacking Ensemble
    stacking_clf = StackingClassifier(estimators=[
        ('svm', svm),
        ('rf', rf),
        ('logreg', logreg)
    ], final_estimator=meta_model, cv=3)

    # Entrenar y evaluar el ensemble
    stacking_clf.fit(x_train, y_train)
    y_pred = stacking_clf.predict(x_test)
    score = f1_score(y_test, y_pred, average='weighted')
    return score

# Crear el estudio de Optuna y optimizar
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Resultados de Optuna
print("Mejores parámetros:", study.best_params)
print("Mejor F1 ponderado:", study.best_value)

# Entrenamiento final con los mejores parámetros encontrados
best_params = study.best_params
svm = SVC(C=best_params['c_svm'], kernel=best_params['kernel_svm'], gamma=best_params.get('gamma_svm', 'scale'), probability=True, random_state=42)
rf = RandomForestClassifier(n_estimators=best_params['n_estimators_rf'], max_depth=50, min_samples_leaf=3, 
                            max_features=best_params['max_features_rf'], random_state=42)
logreg = LogisticRegression(C=best_params['c_logreg'], max_iter=1000, random_state=42)

# Configuración del meta-modelo de nivel superior basado en los mejores parámetros encontrados
if best_params['meta_model'] == 'LogisticRegression':
    meta_model = LogisticRegression(C=best_params['c_meta'], max_iter=1000, random_state=42)
else:
    meta_model = MultinomialNB(alpha=best_params['alpha_meta'])

# Crear y entrenar el modelo Stacking final
stacking_clf = StackingClassifier(estimators=[
    ('svm', svm),
    ('rf', rf),
    ('logreg', logreg)
], final_estimator=meta_model, cv=3)

stacking_clf.fit(x_train, y_train)
y_pred = stacking_clf.predict(x_test)

# Informe de clasificación final
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=['No Hate', 'Hate']))
# Out:
# [I 2024-11-11 17:30:38,838] A new study created in memory with name: no-name-8366138f-bea2-4016-95a8-4b013ab440e0
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:39,589] Trial 0 finished with value: 0.2951877133105802 and parameters: {'c_svm': 1.2126835263164495, 'kernel_svm': 'linear', 'n_estimators_rf': 20, 'max_features_rf': 0.1, 'c_logreg': 0.9355925645438166, 'meta_model': 'MultinomialNB', 'alpha_meta': 0.6274733815469592}. Best is trial 0 with value: 0.2951877133105802.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:40,322] Trial 1 finished with value: 0.2951877133105802 and parameters: {'c_svm': 0.15994035167220538, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 35, 'max_features_rf': 'sqrt', 'c_logreg': 0.47470234701203273, 'meta_model': 'MultinomialNB', 'alpha_meta': 0.32469326066106874}. Best is trial 0 with value: 0.2951877133105802.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:41,159] Trial 2 finished with value: 0.2951877133105802 and parameters: {'c_svm': 9.210145718833596, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 40, 'max_features_rf': 'sqrt', 'c_logreg': 0.7597167159120022, 'meta_model': 'MultinomialNB', 'alpha_meta': 0.24337752111558714}. Best is trial 0 with value: 0.2951877133105802.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:30:42,041] Trial 3 finished with value: 0.2951877133105802 and parameters: {'c_svm': 0.3841950383135195, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 50, 'max_features_rf': 'sqrt', 'c_logreg': 1.077924876829463, 'meta_model': 'MultinomialNB', 'alpha_meta': 0.6305180629064695}. Best is trial 0 with value: 0.2951877133105802.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:30:43,061] Trial 4 finished with value: 0.7197759775977598 and parameters: {'c_svm': 1.0703768202073405, 'kernel_svm': 'linear', 'n_estimators_rf': 15, 'max_features_rf': 0.5, 'c_logreg': 1.2915297413973168, 'meta_model': 'LogisticRegression', 'c_meta': 1.535158336618572}. Best is trial 4 with value: 0.7197759775977598.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:30:43,752] Trial 5 finished with value: 0.7201680168016802 and parameters: {'c_svm': 0.5940165779510383, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 10, 'max_features_rf': 0.2, 'c_logreg':
 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 45, 'max_features_rf': 0.1, 'c_logreg': 0.5989703102641659, 'meta_model': 'LogisticRegression', 'c_meta': 0.9368864396307723}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:00,178] Trial 20 finished with value: 0.7550796269906748 and parameters: {'c_svm': 0.5859300176807731, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 0.1, 'c_logreg': 0.16286432848265528, 'meta_model': 'LogisticRegression', 'c_meta': 9.778626545329312}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:01,146] Trial 21 finished with value: 0.7550796269906748 and parameters: {'c_svm': 0.7182802030575376, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 0.1, 'c_logreg': 0.1801827576430657, 'meta_model': 'LogisticRegression', 'c_meta': 8.626388129826212}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:02,010] Trial 22 finished with value: 0.7397919791979197 and parameters: {'c_svm': 0.8444279147553977, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 30, 'max_features_rf': 0.1, 'c_logreg': 0.1912642699500582, 'meta_model': 'LogisticRegression', 'c_meta': 9.042033373106419}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:03,044] Trial 23 finished with value: 0.7395318127250899 and parameters: {'c_svm': 1.46896714559579, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 45, 'max_features_rf': 0.1, 'c_logreg': 0.16475702480911816, 'meta_model': 'LogisticRegression', 'c_meta': 4.712499531046161}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:03,934] Trial 24 finished with value: 0.7401560156015602 and parameters: {'c_svm': 0.28594997062055, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 35, 'max_features_rf': 0.1, 'c_logreg': 0.10540938739025417, 'meta_model': 'LogisticRegression', 'c_meta': 5.0750141330588425}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:04,657] Trial 25 finished with value: 0.72 and parameters: {'c_svm': 0.7811400468259002, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 50, 'max_features_rf': 'log2', 'c_logreg': 0.30164728848415884, 'meta_model': 'LogisticRegression', 'c_meta': 9.636677160141485}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:05,636] Trial 26 finished with value: 0.7540985206878426 and parameters: {'c_svm': 1.9138741219757864, 'kernel_svm': 'linear', 'n_estimators_rf': 40, 'max_features_rf': 0.1, 'c_logreg': 0.1573715087322372, 'meta_model': 'LogisticRegression', 'c_meta': 3.165143468254213}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:06,738] Trial 27 finished with value: 0.73016201620162 and parameters: {'c_svm': 0.4360506703621301, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 35, 'max_features_rf': 0.2, 'c_logreg': 0.25717124290994625, 'meta_model': 'LogisticRegression', 'c_meta': 6.925310582274551}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:07,529] Trial 28 finished with value: 0.7352186742016954 and parameters: {'c_svm': 0.21859737661622802, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 25, 'max_features_rf': 0.1, 'c_logreg': 0.13224869393560842, 'meta_model': 'LogisticRegression', 'c_meta': 2.861924797415591}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:31:08,537] Trial 29 finished with value: 0.2951877133105802 and parameters: {'c_svm': 1.3415210163502305, 'kernel_svm': 'linear', 'n_estimators_rf': 45, 'max_features_rf': 0.1, 'c_logreg': 0.6308232143005221, 'meta_model': 'MultinomialNB', 'alpha_meta': 0.9856567310451754}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:09,351] Trial 30 finished with value: 0.7544177611006879 and parameters: {'c_svm': 3.9861773754279417, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 20, 'max_features_rf': 0.1, 'c_logreg': 0.2082541180436694, 'meta_model': 'LogisticRegression', 'c_meta': 6.088354685607655}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:10,161] Trial 31 finished with value: 0.7544177611006879 and parameters: {'c_svm': 4.426665028399799, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 20, 'max_features_rf': 0.1, 'c_logreg': 0.20808179079707884, 'meta_model': 'LogisticRegression', 'c_meta': 5.579233606227923}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:10,967] Trial 32 finished with value: 0.7544177611006879 and parameters: {'c_svm': 9.039521195042404, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 20, 'max_features_rf': 0.1, 'c_logreg': 0.3455680034007789, 'meta_model': 'LogisticRegression', 'c_meta': 6.385623970796467}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:11,718] Trial 33 finished with value: 0.76 and parameters: {'c_svm': 0.9815317736902999, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 15, 'max_features_rf': 0.1, 'c_logreg': 0.5048499982886924, 'meta_model': 'LogisticRegression', 'c_meta': 3.668476177726929}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:31:12,552] Trial 34 finished with value: 0.2951877133105802 and parameters: {'c_svm': 0.9704201104131823, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 40, 'max_features_rf': 'sqrt', 'c_logreg': 0.5516351917594319, 'meta_model': 'MultinomialNB', 'alpha_meta': 0.9912375732244632}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:13,183] Trial 35 finished with value: 0.7450828770719268 and parameters: {'c_svm': 0.33461692100924684, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 10, 'max_features_rf': 0.1, 'c_logreg': 0.793257826054205, 'meta_model': 'LogisticRegression', 'c_meta': 3.6600257419209337}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:31:14,003] Trial 36 finished with value: 0.2951877133105802 and parameters: {'c_svm': 0.6456388590472402, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 15, 'max_features_rf': 0.2, 'c_logreg': 0.4578905043704062, 'meta_model': 'MultinomialNB', 'alpha_meta': 0.10261374530843603}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:14,921] Trial 37 finished with value: 0.7449043726093152 and parameters: {'c_svm': 1.7712577450455695, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 35, 'max_features_rf': 0.1, 'c_logreg': 0.28785570926543147, 'meta_model': 'LogisticRegression', 'c_meta': 1.9925236006099922}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:15,514] Trial 38 finished with value: 0.7194957983193276 and parameters: {'c_svm': 1.022836478203374, 'kernel_svm': 'linear', 'n_estimators_rf': 15, 'max_features_rf': 'sqrt', 'c_logreg': 0.1332616276513808, 'meta_model': 'LogisticRegression', 'c_meta': 9.464647120827022}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:31:16,195] Trial 39 finished with value: 0.2951877133105802 and parameters: {'c_svm': 0.18178387082640038, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 30, 'max_features_rf': 'log2', 'c_logreg': 0.739475575080593, 'meta_model': 'MultinomialNB', 'alpha_meta': 0.4148742544115913}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:18,073] Trial 40 finished with value: 0.7401560156015602 and parameters: {'c_svm': 0.5112808996166915, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 0.5, 'c_logreg': 0.35333615153273995, 'meta_model': 'LogisticRegression', 'c_meta': 3.8093114450678374}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:18,886] Trial 41 finished with value: 0.7544177611006879 and parameters: {'c_svm': 3.118338877165786, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 20, 'max_features_rf': 0.1, 'c_logreg': 0.22487105408318347, 'meta_model': 'LogisticRegression', 'c_meta': 6.945191700642885}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:19,639] Trial 42 finished with value: 0.7546875546998075 and parameters: {'c_svm': 2.339770255474728, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 15, 'max_features_rf': 0.1, 'c_logreg': 0.1700093753694591, 'meta_model': 'LogisticRegression', 'c_meta': 7.103747245919689}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:20,344] Trial 43 finished with value: 0.7450828770719268 and parameters: {'c_svm': 2.3519365987279692, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 10, 'max_features_rf': 0.1, 'c_logreg': 0.16398019215100237, 'meta_model': 'LogisticRegression', 'c_meta': 7.063933601324086}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:21,048] Trial 44 finished with value: 0.7346620489610163 and parameters: {'c_svm': 1.3179548347740262, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 10, 'max_features_rf': 0.1, 'c_logreg': 0.28436345253193007, 'meta_model': 'LogisticRegression', 'c_meta': 4.87397799088795}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:21,795] Trial 45 finished with value: 0.7446748018304118 and parameters: {'c_svm': 0.8289561163862468, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 15, 'max_features_rf': 0.1, 'c_logreg': 1.451555760922447, 'meta_model': 'LogisticRegression', 'c_meta': 9.97163089261208}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:22,476] Trial 46 finished with value: 0.7194957983193276 and parameters: {'c_svm': 1.0849492466638828, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 15, 'max_features_rf': 'sqrt', 'c_logreg': 0.12222365060806654, 'meta_model': 'LogisticRegression', 'c_meta': 4.124237209198408}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:23,538] Trial 47 finished with value: 0.74 and parameters: {'c_svm': 0.13808452175608416, 'kernel_svm': 'linear', 'n_estimators_rf': 50, 'max_features_rf': 0.1, 'c_logreg': 0.5049650194326502, 'meta_model': 'LogisticRegression', 'c_meta': 7.379904401167354}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:31:24,948] Trial 48 finished with value: 0.2951877133105802 and parameters: {'c_svm': 0.5592979118018121, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 25, 'max_features_rf': 0.5, 'c_logreg': 0.1725922765096294, 'meta_model': 'MultinomialNB', 'alpha_meta': 0.8335333125039922}. Best is trial 13 with value: 0.76.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\2480979492.py:42: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:25,913] Trial 49 finished with value: 0.7291892703433089 and parameters: {'c_svm': 0.7891907349396895, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 35, 'max_features_rf': 0.1, 'c_logreg': 9.826723524200945, 'meta_model': 'LogisticRegression', 'c_meta': 2.1489675889625537}. Best is trial 13 with value: 0.76.
# Mejores parámetros: {'c_svm': 0.1064415044885236, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 40, 'max_features_rf': 0.1, 'c_logreg': 0.32870443877334266, 'meta_model': 'LogisticRegression', 'c_meta': 6.667096841789085}
# Mejor F1 ponderado: 0.76
#               precision    recall  f1-score   support
#
#      No Hate       0.71      0.82      0.76        93
#         Hate       0.82      0.71      0.76       107
#
#     accuracy                           0.76       200
#    macro avg       0.76      0.76      0.76       200
# weighted avg       0.77      0.76      0.76       200

# %% [markdown]
# ### Mejoras

# %% [markdown]
# #### Paso 1: Incluir otros modelos base y probar diferentes meta-modelos
#
# Vamos a añadir Gradient Boosting y K-Nearest Neighbors (KNN) como modelos base. También probaremos con árboles de decisión y Gradient Boosting como meta-modelo.

# %%
import optuna
from sklearn.ensemble import StackingClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# Vectorización con TF-IDF
tfidf = TfidfVectorizer(max_features=1500, ngram_range=(1, 3))
x_tfidf = tfidf.fit_transform(data['Cleaned_Text'])
y = data['Any_Hate']

# Dividir en conjunto de entrenamiento y prueba
x_train, x_test, y_train, y_test = train_test_split(x_tfidf, y, test_size=0.2, random_state=42)

# Función de objetivo para Optuna
def objective(trial):
    # Hiperparámetros para los modelos base
    c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
    kernel_svm = trial.suggest_categorical('kernel_svm', ['linear', 'rbf'])
    gamma_svm = trial.suggest_categorical('gamma_svm', ['scale', 'auto']) if kernel_svm == 'rbf' else 'scale'

    n_estimators_rf = trial.suggest_int('n_estimators_rf', 10, 50, step=5)
    max_features_rf = trial.suggest_categorical('max_features_rf', ['sqrt', 'log2', 0.1, 0.2, 0.5])
    c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
    
    n_neighbors_knn = trial.suggest_int('n_neighbors_knn', 3, 15)
    n_estimators_gb = trial.suggest_int('n_estimators_gb', 50, 150, step=10)
    learning_rate_gb = trial.suggest_float('learning_rate_gb', 0.01, 0.3)

    # Modelos base
    svm = SVC(C=c_svm, kernel=kernel_svm, gamma=gamma_svm, probability=True, random_state=42)
    rf = RandomForestClassifier(n_estimators=n_estimators_rf, max_depth=50, min_samples_leaf=3, 
                                max_features=max_features_rf, random_state=42)
    logreg = LogisticRegression(C=c_logreg, max_iter=1000, random_state=42)
    knn = KNeighborsClassifier(n_neighbors=n_neighbors_knn)
    gb = GradientBoostingClassifier(n_estimators=n_estimators_gb, learning_rate=learning_rate_gb, random_state=42)
    
    # Meta-modelo
    meta_model_choice = trial.suggest_categorical('meta_model', ['LogisticRegression', 'DecisionTree', 'GradientBoosting'])
    if meta_model_choice == 'LogisticRegression':
        c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
        meta_model = LogisticRegression(C=c_meta, max_iter=1000, random_state=42)
    elif meta_model_choice == 'DecisionTree':
        max_depth_tree = trial.suggest_int('max_depth_tree', 3, 10)
        meta_model = DecisionTreeClassifier(max_depth=max_depth_tree, random_state=42)
    else:
        n_estimators_meta_gb = trial.suggest_int('n_estimators_meta_gb', 50, 100, step=10)
        learning_rate_meta_gb = trial.suggest_float('learning_rate_meta_gb', 0.01, 0.3)
        meta_model = GradientBoostingClassifier(n_estimators=n_estimators_meta_gb, learning_rate=learning_rate_meta_gb, random_state=42)

    # Configuración del Stacking Ensemble
    stacking_clf = StackingClassifier(estimators=[
        ('svm', svm),
        ('rf', rf),
        ('logreg', logreg),
        ('knn', knn),
        ('gb', gb)
    ], final_estimator=meta_model, cv=3)

    # Entrenar y evaluar el ensemble
    stacking_clf.fit(x_train, y_train)
    y_pred = stacking_clf.predict(x_test)
    score = f1_score(y_test, y_pred, average='weighted')
    return score

# Crear el estudio de Optuna y optimizar
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Resultados de Optuna
print("Mejores parámetros:", study.best_params)
print("Mejor F1 ponderado:", study.best_value)

# Entrenamiento final con los mejores parámetros encontrados
best_params = study.best_params
svm = SVC(C=best_params['c_svm'], kernel=best_params['kernel_svm'], gamma=best_params.get('gamma_svm', 'scale'), probability=True, random_state=42)
rf = RandomForestClassifier(n_estimators=best_params['n_estimators_rf'], max_depth=50, min_samples_leaf=3, 
                            max_features=best_params['max_features_rf'], random_state=42)
logreg = LogisticRegression(C=best_params['c_logreg'], max_iter=1000, random_state=42)
knn = KNeighborsClassifier(n_neighbors=best_params['n_neighbors_knn'])
gb = GradientBoostingClassifier(n_estimators=best_params['n_estimators_gb'], learning_rate=best_params['learning_rate_gb'], random_state=42)

# Configuración del meta-modelo de nivel superior basado en los mejores parámetros encontrados
if best_params['meta_model'] == 'LogisticRegression':
    meta_model = LogisticRegression(C=best_params['c_meta'], max_iter=1000, random_state=42)
elif best_params['meta_model'] == 'DecisionTree':
    meta_model = DecisionTreeClassifier(max_depth=best_params['max_depth_tree'], random_state=42)
else:
    meta_model = GradientBoostingClassifier(n_estimators=best_params['n_estimators_meta_gb'], 
                                            learning_rate=best_params['learning_rate_meta_gb'], random_state=42)

# Crear y entrenar el modelo Stacking final
stacking_clf = StackingClassifier(estimators=[
    ('svm', svm),
    ('rf', rf),
    ('logreg', logreg),
    ('knn', knn),
    ('gb', gb)
], final_estimator=meta_model, cv=3)

stacking_clf.fit(x_train, y_train)
y_pred = stacking_clf.predict(x_test)

# Informe de clasificación final
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=['No Hate', 'Hate']))
# Out:
# [I 2024-11-11 17:31:27,009] A new study created in memory with name: no-name-cc920844-2e81-4e81-82f2-f46acbe49064
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:31:29,232] Trial 0 finished with value: 0.7287974491345278 and parameters: {'c_svm': 0.49823158346769425, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 15, 'max_features_rf': 'sqrt', 'c_logreg': 0.7149771069955464, 'n_neighbors_knn': 13, 'n_estimators_gb': 120, 'learning_rate_gb': 0.2662985253335246, 'meta_model': 'DecisionTree', 'max_depth_tree': 4}. Best is trial 0 with value: 0.7287974491345278.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:31,448] Trial 1 finished with value: 0.7097679767976797 and parameters: {'c_svm': 8.351781182963848, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 20, 'max_features_rf': 'sqrt', 'c_logreg': 0.3627384771564592, 'n_neighbors_knn': 6, 'n_estimators_gb': 120, 'learning_rate_gb': 0.273432150494731, 'meta_model': 'LogisticRegression', 'c_meta': 5.015147765465607}. Best is trial 0 with value: 0.7287974491345278.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:33,743] Trial 2 finished with value: 0.7191592433189871 and parameters: {'c_svm': 0.49778715872545765, 'kernel_svm': 'linear', 'n_estimators_rf': 25, 'max_features_rf': 0.5, 'c_logreg': 0.16751390135677174, 'n_neighbors_knn': 8, 'n_estimators_gb': 70, 'learning_rate_gb': 0.08774642891359097, 'meta_model': 'LogisticRegression', 'c_meta': 1.439062072584573}. Best is trial 0 with value: 0.7287974491345278.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:31:35,770] Trial 3 finished with value: 0.7139513403919802 and parameters: {'c_svm': 2.864315933682566, 'kernel_svm': 'linear', 'n_estimators_rf': 35, 'max_features_rf': 
 'kernel_svm': 'linear', 'n_estimators_rf': 10, 'max_features_rf': 0.5, 'c_logreg': 2.6447917377148724, 'n_neighbors_knn': 10, 'n_estimators_gb': 60, 'learning_rate_gb': 0.03867171906675423, 'meta_model': 'DecisionTree', 'max_depth_tree': 3}. Best is trial 44 with value: 0.7443888594565958.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:33:15,821] Trial 48 finished with value: 0.71 and parameters: {'c_svm': 2.6035708999746308, 'kernel_svm': 'linear', 'n_estimators_rf': 15, 'max_features_rf': 0.5, 'c_logreg': 3.030522941664529, 'n_neighbors_knn': 9, 'n_estimators_gb': 60, 'learning_rate_gb': 0.046957237310790025, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 60, 'learning_rate_meta_gb': 0.10209913653138641}. Best is trial 44 with value: 0.7443888594565958.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:29: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\3705077027.py:46: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:33:17,385] Trial 49 finished with value: 0.7034702773115558 and parameters: {'c_svm': 1.763770647938416, 'kernel_svm': 'linear', 'n_estimators_rf': 10, 'max_features_rf': 0.5, 'c_logreg': 2.17995659327765, 'n_neighbors_knn': 7, 'n_estimators_gb': 50, 'learning_rate_gb': 0.032156172687950034, 'meta_model': 'LogisticRegression', 'c_meta': 0.13639768569290478}. Best is trial 44 with value: 0.7443888594565958.
# Mejores parámetros: {'c_svm': 0.36847252928964835, 'kernel_svm': 'linear', 'n_estimators_rf': 15, 'max_features_rf': 0.5, 'c_logreg': 2.846469548328978, 'n_neighbors_knn': 12, 'n_estimators_gb': 50, 'learning_rate_gb': 0.04018631242007435, 'meta_model': 'DecisionTree', 'max_depth_tree': 3}
# Mejor F1 ponderado: 0.7443888594565958
#               precision    recall  f1-score   support
#
#      No Hate       0.74      0.70      0.72        93
#         Hate       0.75      0.79      0.77       107
#
#     accuracy                           0.74       200
#    macro avg       0.74      0.74      0.74       200
# weighted avg       0.74      0.74      0.74       200

# %% [markdown]
# #### Paso 2: Ajustar el Número de Folds en la Validación Cruzada (cv)

# %%
# Función de objetivo para Optuna (ajustando 'cv' en el Stacking Ensemble)
def objective(trial):
    # Hiperparámetros para los modelos base
    c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
    kernel_svm = trial.suggest_categorical('kernel_svm', ['linear', 'rbf'])
    gamma_svm = trial.suggest_categorical('gamma_svm', ['scale', 'auto']) if kernel_svm == 'rbf' else 'scale'

    n_estimators_rf = trial.suggest_int('n_estimators_rf', 10, 50, step=5)
    max_features_rf = trial.suggest_categorical('max_features_rf', ['sqrt', 'log2', 0.1, 0.2, 0.5])
    c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
    
    n_neighbors_knn = trial.suggest_int('n_neighbors_knn', 3, 15)
    n_estimators_gb = trial.suggest_int('n_estimators_gb', 50, 150, step=10)
    learning_rate_gb = trial.suggest_float('learning_rate_gb', 0.01, 0.3)

    # Modelos base
    svm = SVC(C=c_svm, kernel=kernel_svm, gamma=gamma_svm, probability=True, random_state=42)
    rf = RandomForestClassifier(n_estimators=n_estimators_rf, max_depth=50, min_samples_leaf=3, 
                                max_features=max_features_rf, random_state=42)
    logreg = LogisticRegression(C=c_logreg, max_iter=1000, random_state=42)
    knn = KNeighborsClassifier(n_neighbors=n_neighbors_knn)
    gb = GradientBoostingClassifier(n_estimators=n_estimators_gb, learning_rate=learning_rate_gb, random_state=42)
    
    # Meta-modelo
    meta_model_choice = trial.suggest_categorical('meta_model', ['LogisticRegression', 'DecisionTree', 'GradientBoosting'])
    if meta_model_choice == 'LogisticRegression':
        c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
        meta_model = LogisticRegression(C=c_meta, max_iter=1000, random_state=42)
    elif meta_model_choice == 'DecisionTree':
        max_depth_tree = trial.suggest_int('max_depth_tree', 3, 10)
        meta_model = DecisionTreeClassifier(max_depth=max_depth_tree, random_state=42)
    else:
        n_estimators_meta_gb = trial.suggest_int('n_estimators_meta_gb', 50, 100, step=10)
        learning_rate_meta_gb = trial.suggest_float('learning_rate_meta_gb', 0.01, 0.3)
        meta_model = GradientBoostingClassifier(n_estimators=n_estimators_meta_gb, learning_rate=learning_rate_meta_gb, random_state=42)

    # Optimización de 'cv'
    cv_folds = trial.suggest_categorical('cv_folds', [3, 5, 10])

    # Configuración del Stacking Ensemble con el número de folds optimizado
    stacking_clf = StackingClassifier(estimators=[
        ('svm', svm),
        ('rf', rf),
        ('logreg', logreg),
        ('knn', knn),
        ('gb', gb)
    ], final_estimator=meta_model, cv=cv_folds)

    # Entrenar y evaluar el ensemble
    stacking_clf.fit(x_train, y_train)
    y_pred = stacking_clf.predict(x_test)
    score = f1_score(y_test, y_pred, average='weighted')
    return score

# Crear el estudio de Optuna y optimizar
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Resultados de Optuna
print("Mejores parámetros:", study.best_params)
print("Mejor F1 ponderado:", study.best_value)

# Entrenamiento final con los mejores parámetros encontrados, incluyendo 'cv_folds'
cv_folds = study.best_params['cv_folds']
stacking_clf = StackingClassifier(estimators=[
    ('svm', svm),
    ('rf', rf),
    ('logreg', logreg),
    ('knn', knn),
    ('gb', gb)
], final_estimator=meta_model, cv=cv_folds)

stacking_clf.fit(x_train, y_train)
y_pred = stacking_clf.predict(x_test)

# Informe de clasificación final
print(classification_report(y_test, y_pred, target_names=['No Hate', 'Hate']))
# Out:
# [I 2024-11-11 17:33:19,115] A new study created in memory with name: no-name-c757df0d-466d-495d-8ef9-96016a09e630
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:33:26,246] Trial 0 finished with value: 0.6193157262905161 and parameters: {'c_svm': 2.376349762258961, 'kernel_svm': 'linear', 'n_estimators_rf': 10, 'max_features_rf': 'log2', 'c_logreg': 1.1441389144563758, 'n_neighbors_knn': 5, 'n_estimators_gb': 130, 'learning_rate_gb': 0.10800643262951973, 'meta_model': 'DecisionTree', 'max_depth_tree': 7, 'cv_folds': 10}. Best is trial 0 with value: 0.6193157262905161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:33:29,589] Trial 1 finished with value: 0.6942751719824891 and parameters: {'c_svm': 1.0450040571707873, 'kernel_svm': 'linear', 'n_estimators_rf': 10, 'max_features_rf': 'log2', 'c_logreg': 4.331716297189893, 'n_neighbors_knn': 9, 'n_estimators_gb': 120, 'learning_rate_gb': 0.21511722019940702, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 50, 'learning_rate_meta_gb': 0.18078750319134412, 'cv_folds': 5}. Best is trial 1 with value: 0.6942751719824891.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:33:38,422] Trial 2 finished with value: 0.74 and parameters: {'c_svm': 0.3592414101967955, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 0.5, 'c_logreg': 0.19784205584186162, 'n_neighbors_knn': 5, 'n_estimators_gb': 60, 'learning_rate_gb': 0.06405161585321248, 'meta_model': 'LogisticRegression', 'c_meta': 5.166032998294113, 'cv_folds': 10}. Best is trial 2 with value: 0.74.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:33:42,306] Trial 3 finished with value: 0.7297839783978398 and parameters: {'c_svm': 0.5953845999231446, 'kernel_svm': 'linear', 'n_estimators_rf': 45, 'max_features_rf': 'sqrt', 'c_logreg': 0.2757558468176813, 'n_neighbors_knn': 13, 'n_estimators_gb': 130, 'learning_rate_gb': 0.17840370819115825, 'meta_model': 'LogisticRegression', 'c_meta': 4.3028769764715395, 'cv_folds': 5}. Best is trial 2 with value: 0.74.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:33:46,111] Trial 4 finished with value: 0.668015037593985 and parameters: {'c_svm': 3.3280368629979695, 'kernel_svm': 'linear', 'n_estimators_rf': 20, 'max_features_rf': 0
with value: 0.74.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:34:35,949] Trial 14 finished with value: 0.7450828770719268 and parameters: {'c_svm': 0.18873913574863577, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 35, 'max_features_rf': 0.2, 'c_logreg': 0.3442515651755264, 'n_neighbors_knn': 6, 'n_estimators_gb': 100, 'learning_rate_gb': 0.10435446831451167, 'meta_model': 'LogisticRegression', 'c_meta': 0.847680855415129, 'cv_folds': 3}. Best is trial 14 with value: 0.7450828770719268.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:34:37,914] Trial 15 finished with value: 0.7291892703433089 and parameters: {'c_svm': 0.14941955053691505, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 35, 'max_features_rf': 0.2, 'c_logreg': 0.4027103626229293, 'n_neighbors_knn': 5, 'n_estimators_gb': 60, 'learning_rate_gb': 0.05716400683801093, 'meta_model': 'LogisticRegression', 'c_meta': 0.4344223583726237, 'cv_folds': 3}. Best is trial 14 with value: 0.7450828770719268.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:34:40,749] Trial 16 finished with value: 0.72 and parameters: {'c_svm': 0.20167882276583882, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 30, 'max_features_rf': 0.5, 'c_logreg': 2.050242979734668, 'n_neighbors_knn': 8, 'n_estimators_gb': 90, 'learning_rate_gb': 0.012345580920838983, 'meta_model': 'LogisticRegression', 'c_meta': 0.7609130562088392, 'cv_folds': 3}. Best is trial 14 with value: 0.7450828770719268.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:34:42,715] Trial 17 finished with value: 0.7101740174017401 and parameters: {'c_svm': 1.1162675169554188, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 0.2, 'c_logreg': 0.14211575166575524, 'n_neighbors_knn': 5, 'n_estimators_gb': 50, 'learning_rate_gb': 0.10622012091905134, 'meta_model': 'DecisionTree', 'max_depth_tree': 3, 'cv_folds': 3}. Best is trial 14 with value: 0.7450828770719268.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:34:45,456] Trial 18 finished with value: 0.7297839783978398 and parameters: {'c_svm': 0.2962564241754571, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 35, 'max_features_rf': 0.5, 'c_logreg': 0.5038765239083548, 'n_neighbors_knn': 3, 'n_estimators_gb': 70, 'learning_rate_gb': 0.06288165420542123, 'meta_model': 'LogisticRegression', 'c_meta': 0.14055067920058092, 'cv_folds': 3}. Best is trial 14 with value: 0.7450828770719268.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:34:53,127] Trial 19 finished with value: 0.7248968724218104 and parameters: {'c_svm': 0.7043101464984575, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 25, 'max_features_rf': 0.2, 'c_logreg': 0.19320892317270796, 'n_neighbors_knn': 9, 'n_estimators_gb': 110, 'learning_rate_gb': 0.1283423507425524, 'meta_model': 'LogisticRegression', 'c_meta': 2.072497525919773, 'cv_folds': 10}. Best is trial 14 with value: 0.7450828770719268.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:34:58,437] Trial 20 finished with value: 0.6822241470211644 and parameters: {'c_svm': 0.18563936407746215, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 45, 'max_features_rf': 'log2', 'c_logreg': 0.10494721516069355, 'n_neighbors_knn': 6, 'n_estimators_gb': 70, 'learning_rate_gb': 0.09043217054263593, 'meta_model': 'DecisionTree', 'max_depth_tree': 10, 'cv_folds': 10}. Best is trial 14 with value: 0.7450828770719268.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:35:02,792] Trial 21 finished with value: 0.7349006225155628 and parameters: {'c_svm': 0.44663250584814185, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 0.2, 'c_logreg': 0.2926202387877654, 'n_neighbors_knn': 7, 'n_estimators_gb': 100, 'learning_rate_gb': 0.12970393846080674, 'meta_model': 'LogisticRegression', 'c_meta': 1.3043952757673418, 'cv_folds': 5}. Best is trial 14 with value: 0.7450828770719268.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:35:05,323] Trial 22 finished with value: 0.7550796269906748 and parameters: {'c_svm': 0.32291704553291, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 0.2, 'c_logreg': 0.20202752320235276, 'n_neighbors_knn': 9, 'n_estimators_gb': 90, 'learning_rate_gb': 0.04021280406410663, 'meta_model': 'LogisticRegression', 'c_meta': 0.8057400606836033, 'cv_folds': 3}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:35
 'cv_folds': 3}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:35:32,814] Trial 33 finished with value: 0.7340249305399115 and parameters: {'c_svm': 1.8619845152499457, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 25, 'max_features_rf': 0.1, 'c_logreg': 0.5603259269898568, 'n_neighbors_knn': 9, 'n_estimators_gb': 120, 'learning_rate_gb': 0.1073017600465675, 'meta_model': 'LogisticRegression', 'c_meta': 0.6415115432742154, 'cv_folds': 3}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:35:35,103] Trial 34 finished with value: 0.7343702313946215 and parameters: {'c_svm': 0.20819520014517848, 'kernel_svm': 'linear', 'n_estimators_rf': 30, 'max_features_rf': 0.2, 'c_logreg': 0.2551501121245936, 'n_neighbors_knn': 4, 'n_estimators_gb': 90, 'learning_rate_gb': 0.011117806181635475, 'meta_model': 'LogisticRegression', 'c_meta': 0.25288249176261884, 'cv_folds': 3}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# ...
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:35:47,992] Trial 39 finished with value: 0.7029657213069536 and parameters: {'c_svm': 4.512129608736021, 'kernel_svm': 'linear', 'n_estimators_rf': 35, 'max_features_rf': 0.1, 'c_logreg': 0.34786933807068665, 'n_neighbors_knn': 12, 'n_estimators_gb': 130, 'learning_rate_gb': 0.18922753133576897, 'meta_model': 'LogisticRegression', 'c_meta': 0.15435102280892118, 'cv_folds': 3}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:35:50,202] Trial 40 finished with value: 0.729513805522209 and parameters: {'c_svm': 2.7233671684203706, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 30, 'max_features_rf': 0.2, 'c_logreg': 1.0568925186531377, 'n_neighbors_knn': 13, 'n_estimators_gb': 80, 'learning_rate_gb': 0.025990914565457317, 'meta_model': 'LogisticRegression', 'c_meta': 0.3773516723526552, 'cv_folds': 3}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:35:59,742] Trial 41 finished with value: 0.7349006225155628 and parameters: {'c_svm': 0.3758699911773964, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 0.5, 'c_logreg': 0.1254779252610172, 'n_neighbors_knn': 5, 'n_estimators_gb': 70, 'learning_rate_gb': 0.07596442285506472, 'meta_model': 'LogisticRegression', 'c_meta': 0.8693472295533251, 'cv_folds': 10}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:36:12,604] Trial 42 finished with value: 0.7350861271531788 and parameters: {'c_svm': 0.261506884456496, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 45, 'max_features_rf': 0.5, 'c_logreg': 0.181127521251565, 'n_neighbors_knn': 4, 'n_estimators_gb': 140, 'learning_rate_gb': 0.05231476990473576, 'meta_model': 'LogisticRegression', 'c_meta': 1.681265404448641, 'cv_folds': 10}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:36:17,598] Trial 43 finished with value: 0.6642038774233896 and parameters: {'c_svm': 0.3503229270910313, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 30, 'max_features_rf': 'sqrt', 'c_logreg': 9.588574611704894, 'n_neighbors_knn': 5, 'n_estimators_gb': 60, 'learning_rate_gb': 0.0682644598919815, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 80, 'learning_rate_meta_gb': 0.2971612507515141, 'cv_folds': 10}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:36:24,128] Trial 44 finished with value: 0.74 and parameters: {'c_svm': 0.7157187643511779, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 0.5, 'c_logreg': 0.24328360745302888, 'n_neighbors_knn': 3, 'n_estimators_gb': 150, 'learning_rate_gb': 0.02710112704780739, 'meta_model': 'LogisticRegression', 'c_meta': 3.0721493024130506, 'cv_folds': 5}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:36:31,218] Trial 45 finished with value: 0.7191592433189871 and parameters: {'c_svm': 0.13198979672535563, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 45, 'max_features_rf': 'sqrt', 'c_logreg': 0.6418471026917405, 'n_neighbors_knn': 7, 'n_estimators_gb': 100, 'learning_rate_gb': 0.049671584099529556, 'meta_model': 'LogisticRegression', 'c_meta': 9.150825244150905, 'cv_folds': 10}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:36:36,515] Trial 46 finished with value: 0.729513805522209 and parameters: {'c_svm': 0.5484030045022312, 'kernel_svm': 'linear', 'n_estimators_rf': 35, 'max_features_rf': 0.5, 'c_logreg': 0.44360421613984996, 'n_neighbors_knn': 6, 'n_estimators_gb': 110, 'learning_rate_gb': 0.2293157745261229, 'meta_model': 'LogisticRegression', 'c_meta': 0.6813629699835908, 'cv_folds': 5}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:36:38,975] Trial 47 finished with value: 0.7401560156015602 and parameters: {'c_svm': 0.23027657063254484, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 0.2, 'c_logreg': 0.32932296061311445, 'n_neighbors_knn': 5, 'n_estimators_gb': 90, 'learning_rate_gb': 0.11949793399433509, 'meta_model': 'LogisticRegression', 'c_meta': 4.088324146351733, 'cv_folds': 3}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:27: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 10)
# [I 2024-11-11 17:36:41,633] Trial 48 finished with value: 0.74 and parameters: {'c_svm': 0.23197073976611077, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 50, 'max_features_rf': 0.2, 'c_logreg': 0.3098451277380924, 'n_neighbors_knn': 9, 'n_estimators_gb': 90, 'learning_rate_gb': 0.1282360697490027, 'meta_model': 'LogisticRegression', 'c_meta': 0.3044782145723827, 'cv_folds': 3}. Best is trial 22 with value: 0.7550796269906748.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1537669267.py:10: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:36:44,016] Trial 49 finished with value: 0.7003603242918627 and parameters: {'c_svm': 0.15745858117844055, 'kernel_svm': 'rbf', 'gamma_svm': 'scale', 'n_estimators_rf': 40, 'max_features_rf': 0.2, 'c_logreg': 1.5617750706849263, 'n_neighbors_knn': 7, 'n_estimators_gb': 80, 'learning_rate_gb': 0.14836095644372904, 'meta_model': 'DecisionTree', 'max_depth_tree': 7, 'cv_folds': 3}. Best is trial 22 with value: 0.7550796269906748.
# Mejores parámetros: {'c_svm': 0.32291704553291, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 40, 'max_features_rf': 0.2, 'c_logreg': 0.20202752320235276, 'n_neighbors_knn': 9, 'n_estimators_gb': 90, 'learning_rate_gb': 0.04021280406410663, 'meta_model': 'LogisticRegression', 'c_meta': 0.8057400606836033, 'cv_folds': 3}
# Mejor F1 ponderado: 0.7550796269906748
#               precision    recall  f1-score   support
#
#      No Hate       0.74      0.70      0.72        93
#         Hate       0.75      0.79      0.77       107
#
#     accuracy                           0.74       200
#    macro avg       0.74      0.74      0.74       200
# weighted avg       0.74      0.74      0.74       200

# %% [markdown]
# #### Paso 3: Ajustar Hiperparámetros de Modelos Individuales con Mayor Precisión

# %%
# Función de objetivo para Optuna con ajuste fino de hiperparámetros
def objective(trial):
    # Hiperparámetros para los modelos base, con ajustes más precisos
    c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
    kernel_svm = trial.suggest_categorical('kernel_svm', ['linear', 'rbf'])
    gamma_svm = trial.suggest_categorical('gamma_svm', ['scale', 'auto']) if kernel_svm == 'rbf' else 'scale'

    n_estimators_rf = trial.suggest_int('n_estimators_rf', 10, 30, step=2)  # Reducción de rango y paso
    max_features_rf = trial.suggest_categorical('max_features_rf', ['sqrt', 'log2', 0.1, 0.15, 0.2])

    c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística

    n_neighbors_knn = trial.suggest_int('n_neighbors_knn', 8, 15)  # Enfocado en el rango óptimo
    n_estimators_gb = trial.suggest_int('n_estimators_gb', 100, 150, step=10)
    learning_rate_gb = trial.suggest_float('learning_rate_gb', 0.05, 0.15, step=0.01)  # Ajuste más fino

    # Configuración de los modelos base con los hiperparámetros ajustados
    svm = SVC(C=c_svm, kernel=kernel_svm, gamma=gamma_svm, probability=True, random_state=42)
    rf = RandomForestClassifier(n_estimators=n_estimators_rf, max_depth=50, min_samples_leaf=3, 
                                max_features=max_features_rf, random_state=42)
    logreg = LogisticRegression(C=c_logreg, max_iter=1000, random_state=42)
    knn = KNeighborsClassifier(n_neighbors=n_neighbors_knn)
    gb = GradientBoostingClassifier(n_estimators=n_estimators_gb, learning_rate=learning_rate_gb, random_state=42)
    
    # Meta-modelo
    meta_model_choice = trial.suggest_categorical('meta_model', ['LogisticRegression', 'GradientBoosting'])
    if meta_model_choice == 'LogisticRegression':
        c_meta = trial.suggest_loguniform('c_meta', 0.1, 2)  # Intervalo más específico para C
        meta_model = LogisticRegression(C=c_meta, max_iter=1000, random_state=42)
    else:
        n_estimators_meta_gb = trial.suggest_int('n_estimators_meta_gb', 50, 100, step=5)  # Ajuste fino en el meta-modelo
        learning_rate_meta_gb = trial.suggest_float('learning_rate_meta_gb', 0.05, 0.15, step=0.01)
        meta_model = GradientBoostingClassifier(n_estimators=n_estimators_meta_gb, learning_rate=learning_rate_meta_gb, random_state=42)

    # Configuración del Stacking Ensemble
    stacking_clf = StackingClassifier(estimators=[
        ('svm', svm),
        ('rf', rf),
        ('logreg', logreg),
        ('knn', knn),
        ('gb', gb)
    ], final_estimator=meta_model, cv=3)

    # Entrenar y evaluar el ensemble
    stacking_clf.fit(x_train, y_train)
    y_pred = stacking_clf.predict(x_test)
    score = f1_score(y_test, y_pred, average='weighted')
    return score

# Crear el estudio de Optuna y optimizar
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

# Resultados de Optuna
print("Mejores parámetros:", study.best_params)
print("Mejor F1 ponderado:", study.best_value)

# Entrenamiento final con los mejores parámetros encontrados
best_params = study.best_params
svm = SVC(C=best_params['c_svm'], kernel=best_params['kernel_svm'], gamma=best_params.get('gamma_svm', 'scale'), probability=True, random_state=42)
rf = RandomForestClassifier(n_estimators=best_params['n_estimators_rf'], max_depth=50, min_samples_leaf=3, 
                            max_features=best_params['max_features_rf'], random_state=42)
logreg = LogisticRegression(C=best_params['c_logreg'], max_iter=1000, random_state=42)
knn = KNeighborsClassifier(n_neighbors=best_params['n_neighbors_knn'])
gb = GradientBoostingClassifier(n_estimators=best_params['n_estimators_gb'], learning_rate=best_params['learning_rate_gb'], random_state=42)

# Configuración del meta-modelo de nivel superior basado en los mejores parámetros encontrados
if best_params['meta_model'] == 'LogisticRegression':
    meta_model = LogisticRegression(C=best_params['c_meta'], max_iter=1000, random_state=42)
else:
    meta_model = GradientBoostingClassifier(n_estimators=best_params['n_estimators_meta_gb'], 
                                            learning_rate=best_params['learning_rate_meta_gb'], random_state=42)

# Crear y entrenar el modelo Stacking final
stacking_clf = StackingClassifier(estimators=[
    ('svm', svm),
    ('rf', rf),
    ('logreg', logreg),
    ('knn', knn),
    ('gb', gb)
], final_estimator=meta_model, cv=3)

stacking_clf.fit(x_train, y_train)
y_pred = stacking_clf.predict(x_test)

# Informe de clasificación final
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=['No Hate', 'Hate']))
# Out:
# [I 2024-11-11 17:36:45,873] A new study created in memory with name: no-name-4f2ab053-e2c4-4e3b-8ccb-a24844be7a9a
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:36:48,840] Trial 0 finished with value: 0.74 and parameters: {'c_svm': 1.2882848567251346, 'kernel_svm': 'linear', 'n_estimators_rf': 10, 'max_features_rf': 0.2, 'c_logreg': 0.1933127377748801, 'n_neighbors_knn': 8, 'n_estimators_gb': 140, 'learning_rate_gb': 0.05, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 100, 'learning_rate_meta_gb': 0.15}. Best is trial 0 with value: 0.74.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:36:51,445] Trial 1 finished with value: 0.6942751719824891 and parameters: {'c_svm': 0.8523442437555745, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 12, 'max_features_rf': 0.1, 'c_logreg': 0.22824533652436368, 'n_neighbors_knn': 13, 'n_estimators_gb': 140, 'learning_rate_gb': 0.11, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 95, 'learning_rate_meta_gb': 0.060000000000000005}. Best is trial 0 with value: 0.74.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 2)  # Intervalo más específico para C
# [I 2024-11-11 17:36:54,265] Trial 2 finished with value: 0.7246492960916205 and parameters: {'c_svm': 0.5406052250017885, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 28, 'max_features_rf': 0.2, 'c_logreg': 0.6348818662274271, 'n_neighbors_knn': 12, 'n_estimators_gb': 140, 'learning_rate_gb': 0.14, 'meta_model': 'LogisticRegression', 'c_meta': 0.17413332150847718}. Best is trial 0 with value: 0.74.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 2)  # Intervalo más específico para C
# [I 2024-11-11 17:36:56,567] Trial 3 finished with value: 0.7291892703433089 and parameters: {'c_svm': 0.5275114525616439, 'kernel_svm': 'linear', 'n_estimators_rf': 12, 'max_features_rf': 'log2', 'c_logreg': 1.3129041031994282, 'n_neighbors_knn': 9, 'n_estimators_gb': 130, 'learning_rate_gb': 0.12000000000000001, 'meta_model': 'LogisticRegression', 'c_meta': 0.48679621793951194}. Best is trial 0 with value: 0.74.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:36:59,107] Trial 4 finished with value: 0.7502506265664161 and parameters: {'c_svm': 1.5478886992963752, 'kernel_svm': 'linear', 'n_estimators_rf': 22, 'max_features_rf': 0.2, 'c_logreg': 0.6179440858965548, 'n_neighbors_knn': 12, 'n_estimators_gb': 110, 'learning_rate_gb': 0.13, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 70, 'learning_rate_meta_gb': 0.12000000000000001}. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 2)  # Intervalo más específico para C
# [I 2024-11-11 17:37:01,240] Trial 5 finished with value: 0.7397919791979197 and parameters: {'c_svm': 0.41824311764236827, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 16, 'max_features_rf': 0.15, 'c_logreg': 0.64234192482881, 'n_neighbors_knn': 10, 'n_estimators_gb': 100, 'learning_rate_gb': 0.08, 'meta_model': 'LogisticRegression', 'c_meta': 1.056224085265993}. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:37:03,429] Trial 6 finished with value: 0.71 and parameters: {'c_svm': 0.29212852300689585, 'kernel_svm': 'linear', 'n_estimators_rf': 14, 'max_features_rf': 0.15, 'c_logreg': 0.7756936622032332, 'n_neighbors_knn': 15, 'n_estimators_gb': 100, 'learning_rate_gb': 0.11, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 80, 'learning_rate_meta_gb': 0.09}. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 2)  # Intervalo más específico para C
# [I 2024-11-11 17:37:05,651] Trial 7 finished with value: 0.7183157894736841 and parameters: {'c_svm': 0.1075373902120389, 'kernel_svm': 'linear', 'n_estimators_rf': 28, 'max_features_rf': 'log2', 'c_logreg': 0.8108950453460883, 'n_neighbors_knn': 15, 'n_estimators_gb': 110, 'learning_rate_gb': 0.07, 'meta_model': 'LogisticRegression', 'c_meta': 0.37790218349950866}. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:37:08,480] Trial 8 finished with value: 0.7253095684803003 and parameters: {'c_svm': 0.20601728400197772, 'kernel_svm': 'rbf', 'gamma_svm': 'auto', 'n_estimators_rf': 18, 'max_features_rf': 0.2, 'c_logreg': 0.2450881930918308, 'n_neighbors_knn': 10, 'n_estimators_gb': 140, 'learning_rate_gb': 0.12000000000000001, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 60, 'learning_rate_meta_gb': 0.14}. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 2)  # Intervalo más específico para C
# [I 2024-11-11 17:37:11,053] Trial 9 finished with value: 0.7178081091930951 and parameters: {'c_svm': 0.47033842374428836, 'kernel_svm': 'linear', 'n_estimators_rf': 28, 'max_features_rf': 0.15, 'c_logreg': 0.3125849713667101, 'n_neighbors_knn': 13, 'n_estimators_gb': 120, 'learning_rate_gb': 0.1, 'meta_model': 'LogisticRegression', 'c_meta': 0.14114688045660626}. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:37
. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:38:29,617] Trial 41 finished with value: 0.7042989368355222 and parameters: {'c_svm': 1.3187638194913032, 'kernel_svm': 'linear', 'n_estimators_rf': 10, 'max_features_rf': 0.2, 'c_logreg': 0.2627004360481276, 'n_neighbors_knn': 9, 'n_estimators_gb': 140, 'learning_rate_gb': 0.060000000000000005, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 100, 'learning_rate_meta_gb': 0.15}. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:38:32,514] Trial 42 finished with value: 0.7001800180018003 and parameters: {'c_svm': 1.6402014543177161, 'kernel_svm': 'linear', 'n_estimators_rf': 10, 'max_features_rf': 0.2, 'c_logreg': 0.18885558995019464, 'n_neighbors_knn': 11, 'n_estimators_gb': 150, 'learning_rate_gb': 0.1, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 95, 'learning_rate_meta_gb': 0.14}. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:38:35,353] Trial 43 finished with value: 0.7303245192307694 and parameters: {'c_svm': 1.0189896191365582, 'kernel_svm': 'linear', 'n_estimators_rf': 22, 'max_features_rf': 0.2, 'c_logreg': 0.1362423424603364, 'n_neighbors_knn': 13, 'n_estimators_gb': 140, 'learning_rate_gb': 0.09, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 90, 'learning_rate_meta_gb': 0.11}. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:38:37,790] Trial 44 finished with value: 0.72 and parameters: {'c_svm': 1.2830016019587136, 'kernel_svm': 'linear', 'n_estimators_rf': 12, 'max_features_rf': 0.2, 'c_logreg': 0.3084518378230393, 'n_neighbors_knn': 10, 'n_estimators_gb': 130, 'learning_rate_gb': 0.12000000000000001, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 60, 'learning_rate_meta_gb': 0.08}. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:38:40,411] Trial 45 finished with value: 0.7143227016885554 and parameters: {'c_svm': 1.70194404146494, 'kernel_svm': 'linear', 'n_estimators_rf': 20, 'max_features_rf': 0.1, 'c_logreg': 0.39739136253059415, 'n_neighbors_knn': 8, 'n_estimators_gb': 140, 'learning_rate_gb': 0.07, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 65, 'learning_rate_meta_gb': 0.14}. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:28: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_meta = trial.suggest_loguniform('c_meta', 0.1, 2)  # Intervalo más específico para C
# [I 2024-11-11 17:38:42,745] Trial 46 finished with value: 0.7267391304347827 and parameters: {'c_svm': 0.8455967621983458, 'kernel_svm': 'linear', 'n_estimators_rf': 10, 'max_features_rf': 0.2, 'c_logreg': 0.6242403441740287, 'n_neighbors_knn': 12, 'n_estimators_gb': 130, 'learning_rate_gb': 0.060000000000000005, 'meta_model': 'LogisticRegression', 'c_meta': 0.10531459419926484}. Best is trial 4 with value: 0.7502506265664161.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:38:45,103] Trial 47 finished with value: 0.7602400960384154 and parameters: {'c_svm': 1.4572160504209182, 'kernel_svm': 'linear', 'n_estimators_rf': 14, 'max_features_rf': 0.15, 'c_logreg': 1.1676242694983106, 'n_neighbors_knn': 9, 'n_estimators_gb': 120, 'learning_rate_gb': 0.09, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 70, 'learning_rate_meta_gb': 0.12000000000000001}. Best is trial 47 with value: 0.7602400960384154.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:38:47,507] Trial 48 finished with value: 0.7350861271531788 and parameters: {'c_svm': 1.4118584572925155, 'kernel_svm': 'linear', 'n_estimators_rf': 14, 'max_features_rf': 0.15, 'c_logreg': 1.2134581891929273, 'n_neighbors_knn': 9, 'n_estimators_gb': 120, 'learning_rate_gb': 0.09, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 75, 'learning_rate_meta_gb': 0.12000000000000001}. Best is trial 47 with value: 0.7602400960384154.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 2)  # Intervalo más pequeño
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\1264818300.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 2)  # Menor rango para C en Regresión Logística
# [I 2024-11-11 17:38:49,931] Trial 49 finished with value: 0.6853550940654826 and parameters: {'c_svm': 1.96228347755458, 'kernel_svm': 'linear', 'n_estimators_rf': 16, 'max_features_rf': 0.15, 'c_logreg': 1.574375363876597, 'n_neighbors_knn': 10, 'n_estimators_gb': 120, 'learning_rate_gb': 0.11, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 70, 'learning_rate_meta_gb': 0.13}. Best is trial 47 with value: 0.7602400960384154.
# Mejores parámetros: {'c_svm': 1.4572160504209182, 'kernel_svm': 'linear', 'n_estimators_rf': 14, 'max_features_rf': 0.15, 'c_logreg': 1.1676242694983106, 'n_neighbors_knn': 9, 'n_estimators_gb': 120, 'learning_rate_gb': 0.09, 'meta_model': 'GradientBoosting', 'n_estimators_meta_gb': 70, 'learning_rate_meta_gb': 0.12000000000000001}
# Mejor F1 ponderado: 0.7602400960384154
#               precision    recall  f1-score   support
#
#      No Hate       0.72      0.80      0.76        93
#         Hate       0.80      0.73      0.76       107
#
#     accuracy                           0.76       200
#    macro avg       0.76      0.76      0.76       200
# weighted avg       0.76      0.76      0.76       200

# %% [markdown]
# #### Opción con MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
import optuna

# Definir la función objetivo de Optuna para optimizar el ensemble
def objective(trial):
    # Hiperparámetros para cada modelo
    alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
    c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
    kernel_svm = trial.suggest_categorical('kernel_svm', ['linear', 'rbf'])
    gamma_svm = 'auto' if kernel_svm == 'rbf' else 'scale'
    n_estimators_rf = trial.suggest_int('n_estimators_rf', 50, 150, step=10)
    max_features_rf = trial.suggest_categorical('max_features_rf', ['sqrt', 'log2'])
    c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)

    # Instancias de modelos con hiperparámetros ajustados
    nb = MultinomialNB(alpha=alpha_nb)
    svm = SVC(C=c_svm, kernel=kernel_svm, gamma=gamma_svm, probability=True)
    rf = RandomForestClassifier(n_estimators=n_estimators_rf, max_features=max_features_rf, max_depth=20, random_state=42)
    logreg = LogisticRegression(C=c_logreg, max_iter=1000, random_state=42)
    
    # Ajuste de pesos en el ensemble
    weight_nb = trial.suggest_float('weight_nb', 0.1, 1.0)
    weight_svm = trial.suggest_float('weight_svm', 0.1, 1.0)
    weight_rf = trial.suggest_float('weight_rf', 0.1, 1.0)
    weight_logreg = trial.suggest_float('weight_logreg', 0.1, 1.0)
    
    # Creación del ensemble con VotingClassifier
    voting_clf = VotingClassifier(estimators=[
        ('nb', nb),
        ('svm', svm),
        ('rf', rf),
        ('logreg', logreg)],
        voting='soft', weights=[weight_nb, weight_svm, weight_rf, weight_logreg])
    
    # Validación cruzada para evaluar el desempeño del ensemble
    score = cross_val_score(voting_clf, x_train, y_train, cv=5, scoring='accuracy').mean()
    return score

# Optimización con Optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)  # Aumentar el número de pruebas según el tiempo disponible

# Entrenar el ensemble final con los mejores hiperparámetros encontrados
best_params = study.best_params
print("Mejores parámetros:", best_params)

# Instanciar modelos con los mejores parámetros para entrenar el modelo final
nb = MultinomialNB(alpha=best_params['alpha_nb'])
svm = SVC(C=best_params['c_svm'], kernel=best_params['kernel_svm'], gamma=best_params.get('gamma_svm', 'scale'), probability=True)
rf = RandomForestClassifier(n_estimators=best_params['n_estimators_rf'], max_features=best_params['max_features_rf'], max_depth=20, random_state=42)
logreg = LogisticRegression(C=best_params['c_logreg'], max_iter=1000, random_state=42)

# VotingClassifier con los mejores pesos
voting_clf = VotingClassifier(estimators=[
    ('nb', nb),
    ('svm', svm),
    ('rf', rf),
    ('logreg', logreg)],
    voting='soft', weights=[best_params['weight_nb'], best_params['weight_svm'], best_params['weight_rf'], best_params['weight_logreg']])

# Entrenar el ensemble final
voting_clf.fit(x_train, y_train)
y_pred = voting_clf.predict(x_test)

# Evaluación final
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=['No Hate', 'Hate']))
# Out:
# [I 2024-11-11 17:38:52,293] A new study created in memory with name: no-name-a626ab5f-aea3-4171-9b2c-0fdaf330b91b
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:38:54,198] Trial 0 finished with value: 0.7025 and parameters: {'alpha_nb': 0.6928793155311488, 'c_svm': 1.4924911135631513, 'kernel_svm': 'linear', 'n_estimators_rf': 150, 'max_features_rf': 'sqrt', 'c_logreg': 0.15859029642422995, 'weight_nb': 0.16951312465195062, 'weight_svm': 0.9922788373585463, 'weight_rf': 0.2692705226772004, 'weight_logreg': 0.2225877779889596}. Best is trial 0 with value: 0.7025.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:38:55,471] Trial 1 finished with value: 0.7175 and parameters: {'alpha_nb': 0.22524783159140385, 'c_svm': 0.14734174463286034, 'kernel_svm': 'rbf', 'n_estimators_rf': 80, 'max_features_rf': 'sqrt', 'c_logreg': 0.9156698495445774, 'weight_nb': 0.45808907202756366, 'weight_svm': 0.9658572670014102, 'weight_rf': 0.68077223369052, 'weight_logreg': 0.2709349835215247}. Best is trial 1 with value: 0.7175.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:38:56,661] Trial 2 finished with value: 0.7224999999999999 and parameters: {'alpha_nb': 1.0580435412598836, 'c_svm': 7.852731246004616, 'kernel_svm': 'rbf', 'n_estimators_rf': 60, 'max_features_rf': 'sqrt', 'c_logreg': 2.1983482530617517, 'weight_nb': 0.2745931214988254, 'weight_svm': 0.12085659630581487, 'weight_rf': 0.3636722912948661, 'weight_logreg': 0.6255501567725134}. Best is trial 2 with value: 0.7224999999999999.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:38:58,174] Trial 3 finished with value: 0.705 and parameters: {'alpha_nb': 9.007903767198323, 'c_svm': 5.828318425396498, 'kernel_svm': 'linear', 'n_estimators_rf': 90, 'max_features_rf': 'sqrt', 'c_logreg': 6.694455439851333, 'weight_nb': 0.536534585901798, 'weight_svm': 0.3394342348013427, 'weight_rf': 0.15816226585739315, 'weight_logreg': 0.4840833165695678}. Best is trial 2 with value: 0.7224999999999999.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:38:59,415] Trial 4 finished with value: 0.7224999999999999 and parameters: {'alpha_nb': 0.6374873849078668, 'c_svm': 0.33809227899145444, 'kernel_svm': 'linear', 'n_estimators_rf': 100, 'max_features_rf': 'log2', 'c_logreg': 9.490505976241385, 'weight_nb': 0.7949598450835077, 'weight_svm': 0.430621392493031, 'weight_rf': 0.9848303055847188, 'weight_logreg': 0.239260672334185}. Best is trial 2 with value: 0.7224999999999999.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:39:01,117] Trial 5 finished with value: 0.70625 and parameters: {'alpha_nb': 0.09825057694787429, 'c_svm': 1.5301848449797473, 'kernel_svm': 'linear', 'n_estimators_rf': 130, 'max_features_rf': 'sqrt', 'c_logreg': 7.212942411929719, 'weight_nb': 0.6426726894472087, 'weight_svm': 0.6244157303940744, 'weight_rf': 0.45501124425167805, 'weight_logreg': 0.914368920810759}. Best is trial 2 with value: 0.7224999999999999.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:39:02,778] Trial 6 finished with value: 0.7012499999999999 and parameters: {'alpha_nb': 0.03240887687819027, 'c_svm': 0.7805485287917949, 'kernel_svm': 'linear', 'n_estimators_rf': 130, 'max_features_rf': 'sqrt', 'c_logreg': 2.9045677126068274, 'weight_nb': 0.6958312502138373, 'weight_svm': 0.2523992116880287, 'weight_rf': 0.6949269976837609, 'weight_logreg': 0.7716948824669143}. Best is trial 2 with value: 0.7224999999999999.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:39
. Best is trial 88 with value: 0.7362500000000001.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:41:30,120] Trial 96 finished with value: 0.7224999999999999 and parameters: {'alpha_nb': 7.824307612398946, 'c_svm': 1.655340687429729, 'kernel_svm': 'rbf', 'n_estimators_rf': 100, 'max_features_rf': 'log2', 'c_logreg': 8.328340492629783, 'weight_nb': 0.10052945722967806, 'weight_svm': 0.23702599676800595, 'weight_rf': 0.6400862309452713, 'weight_logreg': 0.3646112614015067}. Best is trial 88 with value: 0.7362500000000001.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:41:31,771] Trial 97 finished with value: 0.7362500000000001 and parameters: {'alpha_nb': 3.207527892733795, 'c_svm': 1.4150212814214038, 'kernel_svm': 'rbf', 'n_estimators_rf': 120, 'max_features_rf': 'sqrt', 'c_logreg': 5.992066144286917, 'weight_nb': 0.14154309931755274, 'weight_svm': 0.2609578288166934, 'weight_rf': 0.523099094855244, 'weight_logreg': 0.4763555012069031}. Best is trial 88 with value: 0.7362500000000001.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:41:33,442] Trial 98 finished with value: 0.7275 and parameters: {'alpha_nb': 2.520426040313465, 'c_svm': 1.3922601832379107, 'kernel_svm': 'rbf', 'n_estimators_rf': 120, 'max_features_rf': 'sqrt', 'c_logreg': 4.977822316095206, 'weight_nb': 0.1421238175285961, 'weight_svm': 0.26670340328996933, 'weight_rf': 0.7027252643413456, 'weight_logreg': 0.4810549129900208}. Best is trial 88 with value: 0.7362500000000001.
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:12: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha_nb = trial.suggest_loguniform('alpha_nb', 1e-3, 1e1)  # Ajuste de suavización para MultinomialNB
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_svm = trial.suggest_loguniform('c_svm', 0.1, 10)
# C:\Users\maria\AppData\Local\Temp\ipykernel_27660\917408468.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   c_logreg = trial.suggest_loguniform('c_logreg', 0.1, 10)
# [I 2024-11-11 17:41:35,124] Trial 99 finished with value: 0.7325 and parameters: {'alpha_nb': 5.256847483681967, 'c_svm': 2.286757904570975, 'kernel_svm': 'rbf', 'n_estimators_rf': 120, 'max_features_rf': 'sqrt', 'c_logreg': 6.533834307487181, 'weight_nb': 0.12830204898118266, 'weight_svm': 0.33081056495377725, 'weight_rf': 0.5292102916463937, 'weight_logreg': 0.3815057489360809}. Best is trial 88 with value: 0.7362500000000001.
# Mejores parámetros: {'alpha_nb': 8.724775067692846, 'c_svm': 1.3447370609913554, 'kernel_svm': 'rbf', 'n_estimators_rf': 110, 'max_features_rf': 'sqrt', 'c_logreg': 7.769671437939925, 'weight_nb': 0.1310214747761662, 'weight_svm': 0.24383860327824347, 'weight_rf': 0.5204970572817637, 'weight_logreg': 0.41946865670001593}
#               precision    recall  f1-score   support
#
#      No Hate       0.65      0.83      0.73        93
#         Hate       0.80      0.61      0.69       107
#
#     accuracy                           0.71       200
#    macro avg       0.72      0.72      0.71       200
# weighted avg       0.73      0.71      0.71       200

# %% [markdown]
# ## Guardar el modelo en Joblib

# %%
import joblib
from sklearn.feature_extraction.text import TfidfVectorizer

# Guardar el modelo Stacking Ensemble entrenado
joblib.dump(stacking_clf, "../models/stacking_ensemble_model.joblib")

# Configurar y ajustar el vectorizador TF-IDF con los datos de entrenamiento
tfidf_vectorizer = TfidfVectorizer(max_features=1500, ngram_range=(1, 3))
X_tfidf = tfidf_vectorizer.fit_transform(data['Cleaned_Text'])

# Guardar el vectorizador
joblib.dump(tfidf_vectorizer, "../models/tfidf_vectorizer.joblib")
# Out:
# ['../models/tfidf_vectorizer.joblib']
