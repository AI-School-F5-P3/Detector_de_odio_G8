# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
import optuna
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.ensemble import VotingClassifier

# %%
df = pd.read_csv('youtoxic_english_1000.csv')

# Eliminar las columnas 'CommentId' y 'VideoId'
df = df.drop(columns=['CommentId', 'VideoId'])

# Mostramos las primeras filas y la información del dataset
print("Primeras filas del dataset:")
display(df.head())
print("\nInformación del dataset:")
display(df.info())
# Out:
# Primeras filas del dataset:
#                                                 Text  IsToxic  IsAbusive  \
# 0  If only people would just take a step back and...    False      False
# 1  Law enforcement is not trained to shoot to app...     True       True
# 2  \nDont you reckon them 'black lives matter' ba...     True       True
# 3  There are a very large number of people who do...    False      False
# 4  The Arab dude is absolutely right, he should h...    False      False
#
#    IsThreat  IsProvocative  IsObscene  IsHatespeech  IsRacist  IsNationalist  \
# 0     False          False      False         False     False          False
# 1     False          False      False         False     False          False
# 2     False          False       True         False     False          False
# 3     False          False      False         False     False          False
# 4     False          False      False         False     False          False
#
#    IsSexist  IsHomophobic  IsReligiousHate  IsRadicalism
# 0     False         False            False         False
# 1     False         False            False         False
# 2     False         False            False         False
# 3     False         False            False         False
# 4     False         False            False         False
# Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Text             1000 non-null   object
#  1   IsToxic          1000 non-null   bool
#  2   IsAbusive        1000 non-null   bool
#  3   IsThreat         1000 non-null   bool
#  4   IsProvocative    1000 non-null   bool
#  5   IsObscene        1000 non-null   bool
#  6   IsHatespeech     1000 non-null   bool
#  7   IsRacist         1000 non-null   bool
#  8   IsNationalist    1000 non-null   bool
#  9   IsSexist         1000 non-null   bool
#  10  IsHomophobic     1000 non-null   bool
#  11  IsReligiousHate  1000 non-null   bool
#  12  IsRadicalism     1000 non-null   bool
# dtypes: bool(12), object(1)
# memory usage: 19.7+ KB
# None

# %%
# [Celda 3] - Preparación y limpieza de datos

# Primero mostramos información sobre valores nulos en el dataset
print("Valores nulos por columna antes de la limpieza:")
print(df.isnull().sum())
print("\nTotal de filas antes de la limpieza:", len(df))

# Definimos las columnas que indican contenido dañino
toxic_columns = ['IsToxic', 'IsAbusive', 'IsThreat', 'IsProvocative', 
                'IsObscene', 'IsHatespeech', 'IsRacist', 'IsNationalist',
                'IsSexist', 'IsHomophobic', 'IsReligiousHate', 'IsRadicalism']

# Convertir los valores "TRUE"/"FALSE" a 1/0 en las columnas tóxicas (si es necesario)
df[toxic_columns] = df[toxic_columns].replace({'TRUE': 1, 'FALSE': 0})

# Creamos una nueva columna que será 1 si cualquiera de las categorías es 1
df['is_harmful'] = df[toxic_columns].any(axis=1).astype(int)

# Preparamos X (textos) e y (etiquetas)
X = df['Text']
y = df['is_harmful']

# Mostramos estadísticas finales
print("\nEstadísticas finales:")
print("-" * 50)
print("Distribución de mensajes dañinos vs no dañinos:")
print(y.value_counts(normalize=True))
print("\nDistribución por tipo de contenido dañino:")
for col in toxic_columns:
    positivos = df[col].sum()
    porcentaje = (positivos / len(df)) * 100
    print(f"{col}: {positivos} casos ({porcentaje:.2f}%)")
# Out:
# Valores nulos por columna antes de la limpieza:
# Text               0
# IsToxic            0
# IsAbusive          0
# IsThreat           0
# IsProvocative      0
# IsObscene          0
# IsHatespeech       0
# IsRacist           0
# IsNationalist      0
# IsSexist           0
# IsHomophobic       0
# IsReligiousHate    0
# IsRadicalism       0
# dtype: int64
#
# Total de filas antes de la limpieza: 1000
#
# Estadísticas finales:
# --------------------------------------------------
# Distribución de mensajes dañinos vs no dañinos:
# is_harmful
# 0    0.538
# 1    0.462
# Name: proportion, dtype: float64
#
# Distribución por tipo de contenido dañino:
# IsToxic: 462 casos (46.20%)
# IsAbusive: 353 casos (35.30%)
# IsThreat: 21 casos (2.10%)
# IsProvocative: 161 casos (16.10%)
# IsObscene: 100 casos (10.00%)
# IsHatespeech: 138 casos (13.80%)
# IsRacist: 125 casos (12.50%)
# IsNationalist: 8 casos (0.80%)
# IsSexist: 1 casos (0.10%)
# IsHomophobic: 0 casos (0.00%)
# IsReligiousHate: 12 casos (1.20%)
# IsRadicalism: 0 casos (0.00%)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.15,
    random_state=42,
    stratify=y  # Mantenemos la proporción de clases
)

print("Tamaño del conjunto de entrenamiento:", len(X_train))
print("Tamaño del conjunto de prueba:", len(X_test))
# Out:
# Tamaño del conjunto de entrenamiento: 850
# Tamaño del conjunto de prueba: 150

# %%
vectorizer_1 = TfidfVectorizer(
    max_features=5000,  # Limitamos el número de características
    min_df=2,          # Ignoramos términos que aparecen en menos de 2 documentos
    stop_words='english'  # Removemos stopwords en inglés
)

# Transformamos los textos
X_train_vectorized_1 = vectorizer_1.fit_transform(X_train)
X_test_vectorized_1 = vectorizer_1.transform(X_test)

print("Dimensiones de la matriz de características de entrenamiento:", X_train_vectorized.shape)
# Out:
# Dimensiones de la matriz de características de entrenamiento: (850, 1566)

# %%
final_svm_model = SVC(
    C=109.42844096035671,
    kernel='rbf',
    gamma=1.1662316858478285,
    probability=True,
    random_state=42,
    class_weight=None,
    tol=0.00043366566542372227,
    shrinking=False,
    max_iter=1697
)

# Entrenar el modelo con el conjunto de entrenamiento completo
final_svm_model.fit(X_train_vectorized_1, y_train)

print("Modelo final entrenado con los mejores hiperparámetros!")
# Out:
# Modelo final entrenado con los mejores hiperparámetros!

# %%
import optuna
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score

# Definir la función objetivo para Optuna con MultinomialNB
def objective_nb(trial):
    # Definir los hiperparámetros a optimizar
    alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
    fit_prior = trial.suggest_categorical('fit_prior', [True, False])  # Ajustar o no las probabilidades previas
    
    # Crear el modelo Naive Bayes con los hiperparámetros seleccionados
    nb_model = MultinomialNB(alpha=alpha, fit_prior=fit_prior)
    
    # Evaluar el modelo con validación cruzada
    scores = cross_val_score(nb_model, X_train_vectorized_1, y_train, cv=3, scoring='accuracy')
    accuracy = scores.mean()  # Promedio de accuracy
    
    return accuracy  # Optuna maximiza este valor

# Crear un estudio de optimización para MultinomialNB
study_nb = optuna.create_study(direction='maximize')
study_nb.optimize(objective_nb, n_trials=50)  # Ajusta el número de pruebas según el tiempo disponible

# Resultados de la mejor prueba para MultinomialNB
print("Mejores hiperparámetros para MultinomialNB:")
print(study_nb.best_trial.params)
print("Mejor precisión:", study_nb.best_trial.value)
# Out:
# [I 2024-11-12 01:47:52,717] A new study created in memory with name: no-name-8d77ab77-6fb9-4330-bd00-8c8bd466fb64
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:52,744] Trial 0 finished with value: 0.643520131389041 and parameters: {'alpha': 0.00026653815996022093, 'fit_prior': True}. Best is trial 0 with value: 0.643520131389041.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:52,759] Trial 1 finished with value: 0.6917707659383865 and parameters: {'alpha': 1.8020028020462493, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:52,778] Trial 2 finished with value: 0.6752973672423233 and parameters: {'alpha': 6.758173573320408, 'fit_prior': False}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:52,805] Trial 3 finished with value: 0.6741526899915393 and parameters: {'alpha': 0.8261303391861555, 'fit_prior': False}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:52,826] Trial 4 finished with value: 0.6623782743575707 and parameters: {'alpha': 0.26143958889890234, 'fit_prior': False}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:52,850] Trial 5 finished with value: 0.6600059722291346 and parameters: {'alpha': 0.030338971843024233, 'fit_prior': False}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:52,875] Trial 6 finished with value: 0.5423489108976592 and parameters: {'alpha': 37.97746708554285, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:52,906] Trial 7 finished with value: 0.641168566167322 and parameters: {'alpha': 2.4753881728468547e-05, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:52,926] Trial 8 finished with value: 0.6623658322135404 and parameters: {'alpha': 0.08266190283176135, 'fit_prior': False}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:52,945] Trial 9 finished with value: 0.6611713863866354 and parameters: {'alpha': 0.10639729663472275, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:52,977] Trial 10 finished with value: 0.6423381277061663 and parameters: {'alpha': 0.0023191947796723546, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,006] Trial 11 finished with value: 0.6752973672423233 and parameters: {'alpha': 19.379105222454022, 'fit_prior': False}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,033] Trial 12 finished with value: 0.6788392309096037 and parameters: {'alpha': 3.721523590814628, 'fit_prior': False}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,059] Trial 13 finished with value: 0.6905929096368553 and parameters: {'alpha': 1.869241010945121, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,090] Trial 14 finished with value: 0.6505748270541979 and parameters: {'alpha': 0.005797751892651991, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,126] Trial 15 finished with value: 0.5376457804542213 and parameters: {'alpha': 92.95620758801496, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,160] Trial 16 finished with value: 0.6905970570181986 and parameters: {'alpha': 1.4368741146036639, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,198] Trial 17 finished with value: 0.6811949435126662 and parameters: {'alpha': 0.8121609097236878, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,229] Trial 18 finished with value: 0.6552821048789794 and parameters: {'alpha': 0.01199877335064073, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,266] Trial 19 finished with value: 0.6235214585510708 and parameters: {'alpha': 8.858816862895365, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,315] Trial 20 finished with value: 0.6741153635594485 and parameters: {'alpha': 0.2596210615746715, 'fit_prior': True}. Best is trial 1 with value: 0.6917707659383865.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,355] Trial 21 finished with value: 0.6929569170026045 and parameters: {'alpha': 1.5527264931245244, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,400] Trial 22 finished with value: 0.6882454917964796 and parameters: {'alpha': 1.3179721582563306, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,446] Trial 23 finished with value: 0.6741153635594485 and parameters: {'alpha': 0.2552077015950693, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,496] Trial 24 finished with value: 0.5776348313674746 and parameters: {'alpha': 15.817825035818661, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,537] Trial 25 finished with value: 0.6823645050515105 and parameters: {'alpha': 2.4295991027709527, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,574] Trial 26 finished with value: 0.5376457804542213 and parameters: {'alpha': 84.16191244577142, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,626] Trial 27 finished with value: 0.641160271404635 and parameters: {'alpha': 0.0008279903909179096, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,674] Trial 28 finished with value: 0.6670565205129483 and parameters: {'alpha': 0.04764815537028349, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,716] Trial 29 finished with value: 0.6753015146236666 and parameters: {'alpha': 0.5065308016180023, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,750] Trial 30 finished with value: 0.6399948572471342 and parameters: {'alpha': 1.1206783369482422e-05, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,787] Trial 31 finished with value: 0.6847160702732294 and parameters: {'alpha': 2.71167641227682, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,819] Trial 32 finished with value: 0.6694080857346671 and parameters: {'alpha': 4.783272649725624, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,850] Trial 33 finished with value: 0.6917707659383865 and parameters: {'alpha': 1.7624926989094292, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,885] Trial 34 finished with value: 0.6753015146236666 and parameters: {'alpha': 0.5134183076859662, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,918] Trial 35 finished with value: 0.6752973672423233 and parameters: {'alpha': 8.27493020286847, 'fit_prior': False}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,952] Trial 36 finished with value: 0.5482381924053152 and parameters: {'alpha': 31.357500244491902, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:53,983] Trial 37 finished with value: 0.6623533900695101 and parameters: {'alpha': 0.13410641414323968, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:54,022] Trial 38 finished with value: 0.6741526899915393 and parameters: {'alpha': 0.9659995871126886, 'fit_prior': False}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:54,077] Trial 39 finished with value: 0.6599935300851043 and parameters: {'alpha': 0.027382192067204648, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:54,129] Trial 40 finished with value: 0.6764752235438545 and parameters: {'alpha': 9.004229624788485, 'fit_prior': False}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:54,184] Trial 41 finished with value: 0.6917749133197298 and parameters: {'alpha': 1.7390449889110051, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:54,249] Trial 42 finished with value: 0.6764835183065413 and parameters: {'alpha': 0.5470599047805182, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:54,315] Trial 43 finished with value: 0.6905970570181986 and parameters: {'alpha': 1.4651744082149283, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:54,366] Trial 44 finished with value: 0.6682385241958227 and parameters: {'alpha': 0.1976287971432943, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:54,398] Trial 45 finished with value: 0.6764752235438545 and parameters: {'alpha': 4.3987289816059345, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:54,428] Trial 46 finished with value: 0.643520131389041 and parameters: {'alpha': 0.0001460747054337522, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:54,460] Trial 47 finished with value: 0.674119510940792 and parameters: {'alpha': 20.044187608142366, 'fit_prior': False}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:54,501] Trial 48 finished with value: 0.6611672390052921 and parameters: {'alpha': 0.08513947348339045, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6428\631784351.py:8: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   alpha = trial.suggest_loguniform('alpha', 1e-5, 1e2)  # Parámetro de suavizado
# [I 2024-11-12 01:47:54,542] Trial 49 finished with value: 0.6729375072579172 and parameters: {'alpha': 0.4546067963983225, 'fit_prior': True}. Best is trial 21 with value: 0.6929569170026045.
# Mejores hiperparámetros para MultinomialNB:
# {'alpha': 1.5527264931245244, 'fit_prior': True}
# Mejor precisión: 0.6929569170026045

# %%
# Extraer los mejores hiperparámetros del estudio de MultinomialNB
best_params_nb = study_nb.best_trial.params

# Crear el modelo final con los mejores hiperparámetros
final_nb_model = MultinomialNB(
    alpha=best_params_nb['alpha'],
    fit_prior=best_params_nb['fit_prior']
)

# Entrenar el modelo con el conjunto de entrenamiento completo
final_nb_model.fit(X_train_vectorized, y_train)

# Evaluar el modelo en el conjunto de prueba
y_pred_nb = final_nb_model.predict(X_test_vectorized)

# Calcular y mostrar la precisión y el reporte de clasificación
from sklearn.metrics import accuracy_score, classification_report
accuracy_nb = accuracy_score(y_test, y_pred_nb)
report_nb = classification_report(y_test, y_pred_nb)

print("Accuracy en conjunto de prueba para MultinomialNB:", accuracy_nb)
print("Reporte de clasificación para MultinomialNB:\n", report_nb)
# Out:
# Accuracy en conjunto de prueba para MultinomialNB: 0.72
# Reporte de clasificación para MultinomialNB:
#                precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77        81
#            1       0.76      0.57      0.65        69
#
#     accuracy                           0.72       150
#    macro avg       0.73      0.71      0.71       150
# weighted avg       0.73      0.72      0.71       150

# %%
from sklearn.ensemble import RandomForestClassifier

# Definir la función objetivo para Optuna con RandomForestClassifier
def objective_rf(trial):
    # Definir los hiperparámetros a optimizar
    n_estimators = trial.suggest_int('n_estimators', 50, 300)  # Número de árboles
    max_depth = trial.suggest_int('max_depth', 5, 50)  # Profundidad máxima de cada árbol
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)  # Tamaño mínimo para hacer split
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)  # Tamaño mínimo de muestras en una hoja
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2'])  # Características a considerar
    
    # Crear el modelo Random Forest con los hiperparámetros seleccionados
    rf_model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42
    )
    
    # Evaluar el modelo con validación cruzada
    scores = cross_val_score(rf_model, X_train_vectorized_1, y_train, cv=3, scoring='accuracy')
    accuracy = scores.mean()  # Promedio de accuracy
    
    return accuracy  # Optuna maximiza este valor

# Crear un estudio de optimización para RandomForestClassifier
study_rf = optuna.create_study(direction='maximize')
study_rf.optimize(objective_rf, n_trials=50)  # Ajusta el número de pruebas según el tiempo disponible

# Resultados de la mejor prueba para RandomForestClassifier
print("Mejores hiperparámetros para RandomForestClassifier:")
print(study_rf.best_trial.params)
print("Mejor precisión:", study_rf.best_trial.value)
# Out:
# [I 2024-11-12 01:47:54,633] A new study created in memory with name: no-name-7877bbcc-9040-4d9b-baee-cee150aa2683
# [I 2024-11-12 01:47:55,291] Trial 0 finished with value: 0.6435367209144146 and parameters: {'n_estimators': 64, 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.6435367209144146.
# [I 2024-11-12 01:47:57,429] Trial 1 finished with value: 0.6152806118216958 and parameters: {'n_estimators': 288, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 0 with value: 0.6435367209144146.
# [I 2024-11-12 01:47:59,858] Trial 2 finished with value: 0.6741443952288525 and parameters: {'n_estimators': 174, 'max_depth': 36, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 2 with value: 0.6741443952288525.
# [I 2024-11-12 01:48:01,407] Trial 3 finished with value: 0.6847326597986031 and parameters: {'n_estimators': 119, 'max_depth': 44, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:02,007] Trial 4 finished with value: 0.5376457804542213 and parameters: {'n_estimators': 68, 'max_depth': 47, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:03,720] Trial 5 finished with value: 0.6717720931004164 and parameters: {'n_estimators': 122, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:05,451] Trial 6 finished with value: 0.6694205278786973 and parameters: {'n_estimators': 156, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:06,835] Trial 7 finished with value: 0.5376457804542213 and parameters: {'n_estimators': 185, 'max_depth': 15, 'min_samples_split': 19, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:08,456] Trial 8 finished with value: 0.6529720134706946 and parameters: {'n_estimators': 182, 'max_depth': 38, 'min_samples_split': 14, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:10,673] Trial 9 finished with value: 0.5964639426666003 and parameters: {'n_estimators': 294, 'max_depth': 20, 'min_samples_split': 4, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:12,199] Trial 10 finished with value: 0.5564707443720035 and parameters: {'n_estimators': 235, 'max_depth': 50, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:13,192] Trial 11 finished with value: 0.6141027555201646 and parameters: {'n_estimators': 123, 'max_depth': 39, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:13,908] Trial 12 finished with value: 0.6105691866155709 and parameters: {'n_estimators': 122, 'max_depth': 37, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:15,184] Trial 13 finished with value: 0.5552845933077856 and parameters: {'n_estimators': 226, 'max_depth': 28, 'min_samples_split': 15, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:16,287] Trial 14 finished with value: 0.6823686524328539 and parameters: {'n_estimators': 91, 'max_depth': 42, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:16,917] Trial 15 finished with value: 0.6682468189585097 and parameters: {'n_estimators': 93, 'max_depth': 44, 'min_samples_split': 17, 'min_samples_leaf': 2, 'max_features': 'log2'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:17,665] Trial 16 finished with value: 0.672983128452695 and parameters: {'n_estimators': 94, 'max_depth': 43, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:19,203] Trial 17 finished with value: 0.6835382139716982 and parameters: {'n_estimators': 141, 'max_depth': 23, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:20,128] Trial 18 finished with value: 0.5388236367557524 and parameters: {'n_estimators': 140, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:22,167] Trial 19 finished with value: 0.6752973672423233 and parameters: {'n_estimators': 217, 'max_depth': 23, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 3 with value: 0.6847326597986031.
# [I 2024-11-12 01:48:23,730] Trial 20 finished with value: 0.6858814844307304 and parameters: {'n_estimators': 152, 'max_depth': 32, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 20 with value: 0.6858814844307304.
# [I 2024-11-12 01:48:25,249] Trial 21 finished with value: 0.6882371970337928 and parameters: {'n_estimators': 154, 'max_depth': 32, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:27,335] Trial 22 finished with value: 0.6764918130692282 and parameters: {'n_estimators': 202, 'max_depth': 32, 'min_samples_split': 17, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:28,996] Trial 23 finished with value: 0.685885631812074 and parameters: {'n_estimators': 153, 'max_depth': 33, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:31,153] Trial 24 finished with value: 0.6682592611025399 and parameters: {'n_estimators': 255, 'max_depth': 33, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:32,888] Trial 25 finished with value: 0.685885631812074 and parameters: {'n_estimators': 161, 'max_depth': 24, 'min_samples_split': 7, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:34,474] Trial 26 finished with value: 0.6788392309096037 and parameters: {'n_estimators': 161, 'max_depth': 26, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:36,155] Trial 27 finished with value: 0.672983128452695 and parameters: {'n_estimators': 201, 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:37,539] Trial 28 finished with value: 0.6494467393287877 and parameters: {'n_estimators': 175, 'max_depth': 27, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:39,092] Trial 29 finished with value: 0.6835423613530417 and parameters: {'n_estimators': 139, 'max_depth': 34, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:41,091] Trial 30 finished with value: 0.6729582441646346 and parameters: {'n_estimators': 199, 'max_depth': 29, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:42,844] Trial 31 finished with value: 0.685885631812074 and parameters: {'n_estimators': 156, 'max_depth': 31, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:44,442] Trial 32 finished with value: 0.6800046450671046 and parameters: {'n_estimators': 166, 'max_depth': 24, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:45,844] Trial 33 finished with value: 0.6788475256722905 and parameters: {'n_estimators': 147, 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:47,104] Trial 34 finished with value: 0.6706025315615719 and parameters: {'n_estimators': 103, 'max_depth': 35, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:47,560] Trial 35 finished with value: 0.6352792846596659 and parameters: {'n_estimators': 51, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:49,414] Trial 36 finished with value: 0.6776655219894159 and parameters: {'n_estimators': 190, 'max_depth': 31, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:50,825] Trial 37 finished with value: 0.6706191210869457 and parameters: {'n_estimators': 166, 'max_depth': 25, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:52,495] Trial 38 finished with value: 0.6835423613530417 and parameters: {'n_estimators': 129, 'max_depth': 41, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:55,107] Trial 39 finished with value: 0.6765084025946018 and parameters: {'n_estimators': 273, 'max_depth': 36, 'min_samples_split': 11, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:56,832] Trial 40 finished with value: 0.6753015146236666 and parameters: {'n_estimators': 173, 'max_depth': 29, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:58,263] Trial 41 finished with value: 0.6847119228918861 and parameters: {'n_estimators': 146, 'max_depth': 32, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:48:59,566] Trial 42 finished with value: 0.6835630982597588 and parameters: {'n_estimators': 111, 'max_depth': 40, 'min_samples_split': 14, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:49:01,298] Trial 43 finished with value: 0.6765001078319148 and parameters: {'n_estimators': 159, 'max_depth': 35, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:49:02,656] Trial 44 finished with value: 0.6776489324640421 and parameters: {'n_estimators': 149, 'max_depth': 21, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:49:03,793] Trial 45 finished with value: 0.6752973672423233 and parameters: {'n_estimators': 133, 'max_depth': 17, 'min_samples_split': 11, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:49:05,378] Trial 46 finished with value: 0.6764959604505716 and parameters: {'n_estimators': 184, 'max_depth': 27, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:49:06,111] Trial 47 finished with value: 0.5823255196668823 and parameters: {'n_estimators': 113, 'max_depth': 38, 'min_samples_split': 8, 'min_samples_leaf': 10, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:49:07,303] Trial 48 finished with value: 0.6164543207418837 and parameters: {'n_estimators': 155, 'max_depth': 30, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# [I 2024-11-12 01:49:08,467] Trial 49 finished with value: 0.661196270674696 and parameters: {'n_estimators': 173, 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 21 with value: 0.6882371970337928.
# Mejores hiperparámetros para RandomForestClassifier:
# {'n_estimators': 154, 'max_depth': 32, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
# Mejor precisión: 0.6882371970337928

# %%
# Crear el modelo final con los mejores hiperparámetros
final_rf_model = RandomForestClassifier(
    n_estimators=235,
    max_depth=44,
    min_samples_split=10,
    min_samples_leaf=2,
    max_features='sqrt',
    random_state=42
)

# Entrenar el modelo con el conjunto de entrenamiento completo
final_rf_model.fit(X_train_vectorized_1, y_train)

# Evaluar el modelo en el conjunto de prueba
y_pred_rf = final_rf_model.predict(X_test_vectorized_1)

# Calcular y mostrar la precisión y el reporte de clasificación
accuracy_rf = accuracy_score(y_test, y_pred_rf)
report_rf = classification_report(y_test, y_pred_rf)

print("Accuracy en conjunto de prueba para RandomForestClassifier:", accuracy_rf)
print("Reporte de clasificación para RandomForestClassifier:\n", report_rf)
# Out:
# Accuracy en conjunto de prueba para RandomForestClassifier: 0.7066666666666667
# Reporte de clasificación para RandomForestClassifier:
#                precision    recall  f1-score   support
#
#            0       0.67      0.91      0.77        81
#            1       0.82      0.46      0.59        69
#
#     accuracy                           0.71       150
#    macro avg       0.74      0.69      0.68       150
# weighted avg       0.74      0.71      0.69       150

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import train_test_split
import numpy as np
from scipy import sparse

# 1. Primero dividimos los datos en conjuntos de entrenamiento y prueba
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, 
    test_size=0.01,
    random_state=42,
    stratify=y
)

# Separamos el conjunto temporal en entrenamiento y validación
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp,
    test_size=0.1,
    random_state=42,
    stratify=y_temp
)

# 2. Vectorizamos los datos
vectorizer_2 = TfidfVectorizer(
    min_df=2,
    max_df=0.95,
    max_features=5000
)

# Vectorizamos cada conjunto por separado
X_train_vectorized_2 = vectorizer_2.fit_transform(X_train)
X_val_vectorized = vectorizer_2.transform(X_val)
X_test_vectorized_2 = vectorizer_2.transform(X_test)

# Reducir dimensionalidad
selector = SelectKBest(score_func=chi2, k=1000)
X_train_reduced = selector.fit_transform(X_train_vectorized_2, y_train)
X_val_reduced = selector.transform(X_val_vectorized)
X_test_reduced = selector.transform(X_test_vectorized_2)

print("Dimensiones después de la reducción:")
print("Entrenamiento:", X_train_reduced.shape)
print("Validación:", X_val_reduced.shape)
print("Prueba:", X_test_reduced.shape)

# Integración de MLflow
import mlflow
mlflow.set_experiment("my-experiment")

with mlflow.start_run():
    mlflow.log_params({
        "max_depth": 5,
        "n_estimators": 100,
        "learning_rate": 0.1
    })

    # 4. Creamos y entrenamos el ensemble con bagging
    bagged_ensemble = BaggingClassifier(
        estimator=VotingClassifier(
            estimators=[
                ('random_forest', final_rf_model),
                ('naive_bayes', final_nb_model),
                ('svm', final_svm_model)
            ],
            voting='soft'
        ),
        n_estimators=10,
        max_samples=0.8,
        max_features=0.8,
        random_state=42
    )

    # 5. Implementamos early stopping
    class EarlyStoppingMonitor:
        def __init__(self, patience=3, min_delta=0.001):
            self.patience = patience
            self.min_delta = min_delta
            self.best_score = None
            self.counter = 0
            self.best_model = None
            
        def check(self, model, val_score):
            if self.best_score is None or val_score > self.best_score + self.min_delta:
                self.best_score = val_score
                self.counter = 0
                self.best_model = model
                return False
            else:
                self.counter += 1
                return self.counter >= self.patience

    # Entrenamiento con early stopping
    monitor = EarlyStoppingMonitor(patience=3)
    best_accuracy = 0

    for epoch in range(10):
        # Entrenar el modelo
        bagged_ensemble.fit(X_train_reduced, y_train)
        
        # Evaluar en el conjunto de validación
        val_accuracy = bagged_ensemble.score(X_val_reduced, y_val)
        print(f"Época {epoch + 1}, Accuracy en validación: {val_accuracy:.4f}")
        
        if monitor.check(bagged_ensemble, val_accuracy):
            print("Early stopping activado en época", epoch + 1)
            break

    # Usar el mejor modelo encontrado
    best_model = monitor.best_model if monitor.best_model is not None else bagged_ensemble
# Out:
# Dimensiones después de la reducción:
# Entrenamiento: (891, 1000)
# Validación: (99, 1000)
# Prueba: (10, 1000)
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Época 1, Accuracy en validación: 0.7778
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Época 2, Accuracy en validación: 0.7778
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Época 3, Accuracy en validación: 0.7778
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1697).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Época 4, Accuracy en validación: 0.7778
# Early stopping activado en época 4

# %%
# Evaluar el mejor modelo con threshold
threshold = 0.59

# Predicciones en entrenamiento
y_prob_train = best_model.predict_proba(X_train_reduced)[:, 1]
y_pred_train_thresholded = (y_prob_train >= threshold).astype(int)

# Predicciones en prueba
y_prob_test = best_model.predict_proba(X_test_reduced)[:, 1]
y_pred_test_thresholded = (y_prob_test >= threshold).astype(int)

# Calcular métricas
accuracy_train = accuracy_score(y_train, y_pred_train_thresholded)
accuracy_test = accuracy_score(y_test, y_pred_test_thresholded)
overfitting_percentage = ((accuracy_train - accuracy_test) / accuracy_train) * 100

# Imprimir resultados
print("\nResultados finales:")
print(f"Accuracy en entrenamiento (threshold={threshold}): {accuracy_train:.4f}")
print(f"Accuracy en prueba (threshold={threshold}): {accuracy_test:.4f}")
print(f"Porcentaje de overfitting: {overfitting_percentage:.2f}%")
print("\nReporte de clasificación:")
print(classification_report(y_test, y_pred_test_thresholded))

# Visualizar las características más importantes
if hasattr(selector, 'get_feature_names_out'):
    feature_names = vectorizer_2.get_feature_names_out()
    selected_features = selector.get_support()
    important_features = [(feature_names[i], selector.scores_[i]) 
                         for i in range(len(feature_names)) 
                         if selected_features[i]]
    
    important_features.sort(key=lambda x: x[1], reverse=True)
    print("\nTop 10 características más importantes:")
    for feature, score in important_features[:10]:
        print(f"{feature}: {score:.4f}")
# Out:
# Resultados finales:
# Accuracy en entrenamiento (threshold=0.59): 0.8025
# Accuracy en prueba (threshold=0.59): 0.8000
# Porcentaje de overfitting: 0.31%
#
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83         5
#            1       1.00      0.60      0.75         5
#
#     accuracy                           0.80        10
#    macro avg       0.86      0.80      0.79        10
# weighted avg       0.86      0.80      0.79        10
#
#
# Top 10 características más importantes:
# story: 8.1457
# hang: 7.1270
# raise: 6.6136
# wtf: 5.8197
# lack: 5.2509
# thats: 5.2149
# bags: 5.1603
# reciting: 4.8790
# hard: 4.6901
# bull: 4.6859

# %%
import joblib

# Guardar el vectorizador
joblib.dump(vectorizer_2, 'vectorizer_2.pkl')

# Guardar el selector de características
joblib.dump(selector, 'feature_selector.pkl')

# Guardar el modelo entrenado
joblib.dump(best_model, 'ensemble_model.pkl')
# Out:
# ['ensemble_model.pkl']
